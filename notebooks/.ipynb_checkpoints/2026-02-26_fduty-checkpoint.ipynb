# %%
import numpy as np
import healpy as hp
from healpy.newvisufunc import projview
from astropy.table import Table

import matplotlib
from matplotlib import pyplot as plt

from Corrfunc import mocks
from Corrfunc.utils import convert_rp_pi_counts_to_wp
from scipy import constants
from scipy import stats
import scipy.interpolate as interp
from random import sample
import matplotlib.gridspec as gridspec
from Corrfunc import theory
from astropy.cosmology import FlatLambdaCDM
from Corrfunc.utils import convert_3d_counts_to_cf
import astropy.cosmology.units as cu
import astropy.units as u
import site
site.addsitedir('/oak/stanford/orgs/kipac/users/mahlet/quaia_bias/scripts') 
import quaia
from astropy.coordinates import SkyCoord
import matplotlib.gridspec as gridspec
import seaborn as sns
from matplotlib.colors import LogNorm
import os
import matplotlib.patches as mpatches
import pyccl as ccl
from matplotlib.lines import Line2D
import gc
from matplotlib import cm
from scipy.optimize import curve_fit
from scipy.optimize import minimize
from scipy import linalg
from astropy.cosmology import Planck18
from astropy import constants as const

# %%
matplotlib.rcParams['ytick.labelsize'] = 18
matplotlib.rcParams['xtick.labelsize'] = 18
matplotlib.rcParams['axes.labelsize'] = 22
matplotlib.rcParams['legend.fontsize'] = 18
matplotlib.rcParams['axes.titlesize'] = 20

# %% [markdown]
# # Model using step-function HOD
# ## Define parameters

# %%
G_hi = 20.5

# %%
nthreads = 18

# %%
# Create the bins array
rmin = 0.1 # 0.1 # start higher
rmax = 180.0 # 20.0 #50.0
nbins = 20 #90 #20
rbins = np.logspace(np.log10(rmin), np.log10(rmax), nbins + 1) # Mpc/h https://github.com/manodeep/Corrfunc/issues/202
scale = 'log'

# %%
z_bins = np.array([0.0, 1.0, 2.0, 3.0, 4.6])
z_array = range(len(z_bins)-1)
mask = 0.5

# %%
cosmo_planck18 = ccl.Cosmology(Omega_c=0.265, Omega_b=Planck18.Ob0, h=Planck18.h, Neff = Planck18.Neff, T_CMB = Planck18.Tcmb0.value, m_nu = Planck18.m_nu, sigma8=0.8, n_s=0.95)

# %%
Delta = 200
delta_c = 1.686

# %%
hmf = ccl.halos.MassFuncTinker10()

# %%
NSIDE = 64

# %%
M_max = 15

# %% [markdown]
# ## Define functions

# %%
def a_median(tab_datahi_mask_zbin0, key_zbin0 = ''):
    return 1/(1+np.median(tab_datahi_mask_zbin0['redshift_quaia'+key_zbin0]))

# %%
def b_qso(xi_qq, xi_mm, f):
    
    return np.sqrt(xi_qq/xi_mm-4*f**2/45)-f/3

# %%
def nu(M, delta_c = delta_c, a = 1, cosmo = cosmo_planck18):
    
    sigma = cosmo.sigmaM(M, a = a)
   
    return delta_c/sigma

# %%
def n_g_theory(bins, n_total, a = 1, cosmo = cosmo_planck18, hmf = hmf, recenter = True):

    if recenter == True:
        bins = quaia.recenter(bins)
    nm = hmf(cosmo, bins, a)/cosmo['h']**3
    n_g = nm/(bins*np.log(10))*n_total
    n_g[np.isnan(n_g)]=0
    
    return n_g, nm

def bias(bins, n_m, a = 1, cosmo = cosmo_planck18, mod = False, recenter = True):

    n_g, nm = n_g_theory(bins, n_m, a = a, cosmo = cosmo, recenter = recenter)
    if recenter == True:
        print('recentering')
        bins = quaia.recenter(bins)
    n_g = np.trapz(n_g, bins)
    dn_dm = nm/(bins*np.log(10))

    b1_E_tinker = b1_E_func(nu(bins, a = a, cosmo = cosmo), mod = mod)

    n_m[~np.isfinite(n_m)]=0 
    integrand = dn_dm*n_m
    integrand[np.isnan(integrand)]=0
    
    return bias_function(n_g, integrand, b1_E_tinker, bins, recenter = recenter), n_g

# %%
def b1_E_func(nu, Delta = Delta, delta_c = delta_c, mod = False):

    delta_c = 1.686
    
    if mod == False:
        y = np.log10(Delta)
        A =  1.0+0.24*y*np.exp(-(4/y)**4)
        a = 0.44*y-0.88
        B = 0.183
        b =  1.5
        C = 0.019+0.107*y+0.19*np.exp(-(4/y)**4)
        c = 2.4
        
    else:
        A =  1.0
        a = 0.0906
        B = -4.5002
        b =  2.1419
        C = 4.9148
        c = 2.1419
        
    return 1-A*nu**a/(nu**a+delta_c**a)+B*nu**b+C*nu**c # Jose et al
    
def bias_function(n_g, integrand, b, bins, recenter = True):
    
    if recenter == True:
        print('recentering')
        bins = quaia.recenter(bins)
        
    return 1/n_g*np.trapz(integrand*b, bins)

# %%
def cf_2h(bins, n_m, a, cosmo, cf_matter, recenter = True):
    
    b_q, n_g = bias(bins, n_m, a, cosmo, recenter = recenter)
    return b_q**2*cf_matter, b_q

# %%
def M(bins, n_m, a = 1, cosmo = cosmo_planck18, mod = False, recenter = True, hmf = hmf):

    n_g, nm = n_g_theory(bins, n_m, a = a, cosmo = cosmo, recenter = recenter, hmf = hmf)
    if recenter == True:
        n_g = np.trapz(n_g, quaia.recenter(bins))
        dm = np.diff(bins) 
        dn_dm = nm/(quaia.recenter(bins)*np.log(10))
    else:
        n_g = np.trapz(n_g, bins)
        dn_dm = nm/(bins*np.log(10))

    n_m[~np.isfinite(n_m)]=0 
    integrand = dn_dm*n_m
    integrand[np.isnan(integrand)]=0
    
    if recenter == True:
        return bias_function(n_g, integrand, quaia.recenter(bins), bins, recenter = recenter), n_g
    else:
        return bias_function(n_g, integrand, bins, bins, recenter = recenter), n_g

# %%
def HOD(bins, M_min, fduty):

    n_m=np.zeros(np.shape(quaia.recenter(bins)))
    n_m[quaia.recenter(bins)>=M_min]=fduty

    return n_m

# %%
def n_DM(cosmo, a, M_min, hmf = hmf, M_max = M_max, N = 79): #16.8
    
    bins = np.logspace(M_min, M_max, N)
    nm = hmf(cosmo, bins, a)/cosmo['h']**3 #/u.Mpc**3 # convert to h/Mpc**3
    dn_dm = nm/(bins*np.log(10))
    
    return np.trapz(dn_dm, bins)

# %% [markdown]
# # Visualize the bolometric luminosity-redshift distribution

# %%
fn_selhi = f'../data/maps/selection_function_NSIDE64_G20.5.fits'

# %%
tab_datahi, pixel_indices_datahi_mask, N_datahi_mask, mask_datahi = quaia.read(f'../data/quaia_G20.5.fits', G_hi, fn_selhi, mask_type = 'selfunc')
# Out:
# Number of data sources: 1295502
# {'NAME': '\\emph{{Gaia}}--\\emph{{unWISE}} Quasar Catalog', 'ABBRV': 'Quaia'}
# Column names: <TableColumns names=('source_id','unwise_objid','redshift_quaia','redshift_quaia_err','ra','dec','l','b','phot_g_mean_mag','phot_bp_mean_mag','phot_rp_mean_mag','mag_w1_vg','mag_w2_vg','pm','pmra','pmdec','pmra_error','pmdec_error')>

# %%
cmap = sns.color_palette("rocket", as_cmap=True)
cmap

# %%
# plot!
fig = plt.figure(figsize = (12.5, 10))
gs = gridspec.GridSpec(2, 2, hspace = 0, height_ratios=[1,4], width_ratios=[4,1], wspace = 0)

ax1 = fig.add_subplot(gs[2])

quaia.L_bol(tab_datahi)
h1, xedges, yedges, image = ax1.hist2d(tab_datahi['redshift_quaia'][mask_datahi], tab_datahi['L_bol'][mask_datahi], cmap = cmap, 
                                       bins = [np.linspace(0.08, 4.6, 300), np.logspace(44, 49, 300)], cmin = 1)
ax1.set_ylabel('$L_\mathrm{bol}$ [erg $\mathrm{s}^{-1}]$')
ax1.set_xlabel('$z$')
ax1.set_ylim(2e44, 3e48)
xlim = ax1.get_xlim()
ylim = ax1.get_ylim()
ax1.set_yscale('log')

ax2 = fig.add_subplot(gs[0])
ax2.hist(tab_datahi['redshift_quaia'][mask_datahi], color = 'white', edgecolor = 'black', bins = 30)
ax2.set_ylabel('$N_\mathrm{QSO}$')
ax2.set_yscale('log')
ax2.set_xlim(xlim)
ax2.set_ylim(6,2e5)
ax2.set_xticklabels([])

ax3 = fig.add_subplot(gs[3])
ax3.hist(tab_datahi['L_bol'][mask_datahi], color = 'white', edgecolor = 'black', orientation = 'horizontal', bins = np.logspace(44, 49, 30))
ax3.set_xlabel('$N_\mathrm{QSO}$')
ax3.set_xscale('log')
ax3.set_yscale('log')
ax3.set_yticklabels([])
ax3.set_ylim(ylim)
ax3.set_xlim(2e1,3e5)

plt.show()
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:19: SyntaxWarning: invalid escape sequence '\m'
# <>:27: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:19: SyntaxWarning: invalid escape sequence '\m'
# <>:27: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_20608/1836073741.py:10: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_ylabel('$L_\mathrm{bol}$ [erg $\mathrm{s}^{-1}]$')
# /tmp/ipykernel_20608/1836073741.py:19: SyntaxWarning: invalid escape sequence '\m'
#   ax2.set_ylabel('$N_\mathrm{QSO}$')
# /tmp/ipykernel_20608/1836073741.py:27: SyntaxWarning: invalid escape sequence '\m'
#   ax3.set_xlabel('$N_\mathrm{QSO}$')

# %%
colors = ['Red', 'Orange', 'Green', 'Blue', 'Purple']

# %%
L_bol = [44.5, 45.0, 45.5, 46.0, 46.5]

# %%
zbin_array = [0.0,1.0,2.0,3.0,4.6]
cmap_blue = plt.get_cmap('Blues')(np.linspace(0.333, 0.999, len(L_bol)))

# %%
# plot!
fig = plt.figure(figsize = (12.5, 10))
gs = gridspec.GridSpec(2, 2, hspace = 0, height_ratios=[1,4], width_ratios=[4,1], wspace = 0)
fac_rand = 25

ax1 = fig.add_subplot(gs[2])
ax2 = fig.add_subplot(gs[0])
ax3 = fig.add_subplot(gs[3])

for i in range(len(L_bol)):
    
    tab_datahi_mask_zbin0, tab_randhi_mask_zbin0, key_zbin0, _, _, _, _, _= quaia.make_bins(G_hi, [0, i], True, ['z', 'L_bol'], 
                                                                                         bins = [zbin_array, L_bol], tab_gcat_type = 'data', 
                                                                                          method = ['minmax', 'threshold'], fac_rand = fac_rand, 
                                                                                          mask = mask*100, percentile = True, n_bins = [None, None])
    quaia.L_bol(tab_datahi_mask_zbin0)
    h1, xedges, yedges, image = ax1.hist2d(tab_datahi_mask_zbin0['redshift_quaia'], tab_datahi_mask_zbin0['L_bol'],
                                           cmap = plt.get_cmap('{}s'.format(colors[i])), bins = [np.linspace(0, 1, 300), np.logspace(44, 49, 300)],
                                           cmin = 1, alpha = 0.75)
    xlim = ax1.get_xlim()
    ylim = ax1.get_ylim()
    
    ax2.hist(tab_datahi_mask_zbin0['redshift_quaia'], color = 'white', edgecolor = colors[i], bins = 30, alpha = 0.5)
    ax3.hist(tab_datahi_mask_zbin0['L_bol'], color = 'white', edgecolor = colors[i], orientation = 'horizontal', bins = np.logspace(44, 49, 30), alpha = 0.5, label = '$L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(L_bol[i]))
    
ax1.set_ylabel('$L_\mathrm{bol}$ [erg $\mathrm{s}^{-1}]$')
ax1.set_xlabel('$z$')
ax1.set_ylim(2e44, 3e48)
ax1.set_yscale('log')

ax2.set_ylabel('$N_\mathrm{QSO}$')
ax2.set_yscale('log')
ax2.set_xlim(xlim)
ax2.set_ylim(6,2e5)
ax2.set_xticklabels([])

ax3.set_xlabel('$N_\mathrm{QSO}$')
ax3.set_xscale('log')
ax3.set_yscale('log')
ax3.set_yticklabels([])
ax3.set_ylim(ylim)
ax3.set_xlim(2e1,3e5)
ax3.legend(loc = 'center right', bbox_to_anchor = (-2.1, 0.8)) #2, 0.75

plt.show()
# Out:
# <>:24: SyntaxWarning: invalid escape sequence '\m'
# <>:26: SyntaxWarning: invalid escape sequence '\m'
# <>:31: SyntaxWarning: invalid escape sequence '\m'
# <>:37: SyntaxWarning: invalid escape sequence '\m'
# <>:24: SyntaxWarning: invalid escape sequence '\m'
# <>:26: SyntaxWarning: invalid escape sequence '\m'
# <>:31: SyntaxWarning: invalid escape sequence '\m'
# <>:37: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_20608/3805220712.py:24: SyntaxWarning: invalid escape sequence '\m'
#   ax3.hist(tab_datahi_mask_zbin0['L_bol'], color = 'white', edgecolor = colors[i], orientation = 'horizontal', bins = np.logspace(44, 49, 30), alpha = 0.5, label = '$L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(L_bol[i]))
# /tmp/ipykernel_20608/3805220712.py:26: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_ylabel('$L_\mathrm{bol}$ [erg $\mathrm{s}^{-1}]$')
# /tmp/ipykernel_20608/3805220712.py:31: SyntaxWarning: invalid escape sequence '\m'
#   ax2.set_ylabel('$N_\mathrm{QSO}$')
# /tmp/ipykernel_20608/3805220712.py:37: SyntaxWarning: invalid escape sequence '\m'
#   ax3.set_xlabel('$N_\mathrm{QSO}$')
# G20.5_zmin0.0zmax1.0_Lbolmin44.5: 0.30              225780 vs 324311
# G20.5_zmin0.0zmax1.0_Lbolmin45.0: 0.30              214489 vs 308126
# G20.5_zmin0.0zmax1.0_Lbolmin45.5: 0.31              111779 vs 161096
# G20.5_zmin0.0zmax1.0_Lbolmin46.0: 0.30              17294 vs 24716
# G20.5_zmin0.0zmax1.0_Lbolmin46.5: 0.32              1549 vs 2271

# %% [markdown]
# ## Visualize the bolometric luminosity-threshold cuts

# %%
mask_type = 'selfunc'

# %%
# plot data
bins = np.logspace(44, 49)
wp, rpavg = [], []
mask = 0.5
fn_selhi = '../data/maps/selection_function_NSIDE64_G{}.fits'.format(G_hi)
selfunc_hi = hp.fitsfunc.read_map(fn_selhi)

fn_datahi = '../data/quaia_G{}.fits'.format(G_hi)
tab_datahi = Table.read(fn_datahi)
pixel_indices_datahi = hp.ang2pix(NSIDE, tab_datahi['ra'], tab_datahi['dec'], lonlat=True)
mask_datahi = selfunc_hi[pixel_indices_datahi]>=np.percentile(selfunc_hi, mask*100)

# plot!
fig = plt.figure(figsize = (10, 8))
gs = gridspec.GridSpec(1, 1, wspace = 0)

ax1 = fig.add_subplot(gs[0])
quaia.L_bol(tab_datahi)
ax1.hist(tab_datahi['L_bol'][mask_datahi], bins=bins, histtype = 'step', color='black')

for i in range(len(L_bol)):
    
    tab_datahi_mask_zbin0, tab_randhi_mask_zbin0, key_zbin0, _, _, _, _, _ = quaia.make_bins(G_hi, [0, i], True, ['z', 'L_bol'], 
                                                                                         bins = [zbin_array, L_bol], tab_gcat_type = 'data', 
                                                                                          method = ['minmax', 'threshold'], fac_rand = fac_rand, 
                                                                                          mask = mask*100, percentile = True, n_bins = [None, None])
    quaia.L_bol(tab_datahi_mask_zbin0)
    # quaia.L_bol(tab_randhi_mask_zbin0)
    ax1.hist(tab_datahi_mask_zbin0['L_bol'], label = '$L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(L_bol[i]), 
             bins = bins, color = cmap_blue[i])

ax1.set_xlabel('$L_\mathrm{bol}$ [erg $\mathrm{s}^{-1}]$')
ax1.set_ylabel('$N_\mathrm{QSO}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_ylim(6,2e6)
ax1.set_title('Quaia, $G<{}$'.format(G_hi))
ax1.legend()

plt.show()
# Out:
# <>:29: SyntaxWarning: invalid escape sequence '\m'
# <>:32: SyntaxWarning: invalid escape sequence '\m'
# <>:33: SyntaxWarning: invalid escape sequence '\m'
# <>:29: SyntaxWarning: invalid escape sequence '\m'
# <>:32: SyntaxWarning: invalid escape sequence '\m'
# <>:33: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_20608/1929363783.py:29: SyntaxWarning: invalid escape sequence '\m'
#   ax1.hist(tab_datahi_mask_zbin0['L_bol'], label = '$L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(L_bol[i]),
# /tmp/ipykernel_20608/1929363783.py:32: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_xlabel('$L_\mathrm{bol}$ [erg $\mathrm{s}^{-1}]$')
# /tmp/ipykernel_20608/1929363783.py:33: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_ylabel('$N_\mathrm{QSO}$')
# G20.5_zmin0.0zmax1.0_Lbolmin44.5: 0.30              225780 vs 324311
# G20.5_zmin0.0zmax1.0_Lbolmin45.0: 0.30              214489 vs 308126
# G20.5_zmin0.0zmax1.0_Lbolmin45.5: 0.31              111779 vs 161096
# G20.5_zmin0.0zmax1.0_Lbolmin46.0: 0.30              17294 vs 24716
# G20.5_zmin0.0zmax1.0_Lbolmin46.5: 0.32              1549 vs 2271

# %% [markdown]
# # Implement halo model
# ## Plot HOD: $\langle N(M) \rangle = \begin{cases}f_{duty} & M\geq M_{min} \\ 0 & M<M_{min}\end{cases}$
# ### At fixed $f_{duty}$ and $M_{min}$

# %%
bins = np.logspace(9, M_max, 79)
M_min = 12.8

# %%
M_min_array = [12.86, 12.74, 12.79, 12.82]

# %%
fduty = [0.018, 0.022, 0.056, 0.071]
n_m_array = []
for i in z_array:        
    n_m=np.zeros(np.shape(quaia.recenter(bins)))
    n_m[quaia.recenter(bins)>=10**M_min_array[i]]=fduty[i]
    n_m_array.append(n_m)

# %%
for i in z_array:
        
    plt.plot(quaia.recenter(bins), n_m_array[i], linewidth = 2.5, label = '${:.0f}<z \leq{:.0f}$'.format(i, i+1))

plt.xscale('log')
plt.xlabel('$M (M_\odot)$')
plt.ylabel(r'$\langle N(M) \rangle$')
plt.legend()
plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\l'
# <>:6: SyntaxWarning: invalid escape sequence '\o'
# <>:3: SyntaxWarning: invalid escape sequence '\l'
# <>:6: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_20608/3618045427.py:3: SyntaxWarning: invalid escape sequence '\l'
#   plt.plot(quaia.recenter(bins), n_m_array[i], linewidth = 2.5, label = '${:.0f}<z \leq{:.0f}$'.format(i, i+1))
# /tmp/ipykernel_20608/3618045427.py:6: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$M (M_\odot)$')

# %%
n_m_array, bins_M_min = [], []
for i in range(len(L_bol)):   
    bins_i = np.logspace(M_min_array[0], M_max, 79)
    n_m=np.ones(np.shape(bins_i))*fduty[0]
    n_m_array.append(n_m)
    bins_M_min.append(bins_i)

# %%
n_m_array_2D = []
for i in range(len(L_bol)):   

    n_m_array_2D.append([])
    
    for j in range(len(bins)):
        
        n_m=np.ones(np.shape(bins))*fduty[0]
        n_m_array_2D[i].append(n_m)

# %% [markdown]
# ## Calculate $b_{\mathrm{qq}}(s,z)=\sqrt{\frac{\xi^{(s)}_{\mathrm{qq}}(s)}{\xi^{(r)}_\mathrm{mm}(r)}-\frac{4 \Omega_{\mathrm{m}}^{1.2}(z)}{45}}-\frac{\Omega_{\mathrm{m}}^{0.6}(z)}{3}$
# ### Use a 50th percentile mask

# %%
bins_M_min_array = [np.logspace(np.log10(bins[j]), M_max, 79) for j in range(len(bins))]

# %%
cmap = sns.color_palette("rocket", n_colors = len(bins))
palette = matplotlib.colors.ListedColormap(cmap)
palette

# %% [markdown]
# # Calculate derived parameters
# ## Plot b(z)

# %%
def b_eboss(z):
    
    return 0.278*((1+z)**2-6.565) + 2.393

def b_quaia(b_0, a, cosmo = cosmo_planck18): #quaia):
    
    return b_0/ccl.growth_factor(cosmo, a)

# %%
b_cf20 = np.load('../results/b_cf20_planck18.npy')
b_wp20 = np.load('../results/b_wp20_planck18.npy')

# %% [markdown]
# ## Calculate number density as $n_q \approx \int_0^{\infty} d M \frac{d n}{d M}\langle N(M)\rangle$

# %%
tab_datahi_mask_zbins, selfunc_hi_bins = [], []
for i in range(len(L_bol)):
    
    tab_datahi_mask_zbin0, tab_randhi_mask_zbin0, key_zbin0, _, _, _, selfunc_hi_bin0, _ = quaia.make_bins(G_hi, [0, i], True, ['z', 'L_bol'], 
                                                                                         bins = [zbin_array, L_bol], tab_gcat_type = 'data', 
                                                                                          method = ['minmax', 'threshold'], fac_rand = fac_rand, 
                                                                                          mask = mask*100, percentile = True, n_bins = [None, None])
    tab_datahi_mask_zbins.append(tab_datahi_mask_zbin0['redshift_quaia'])
    selfunc_hi_bins.append(selfunc_hi_bin0)
# Out:
# G20.5_zmin0.0zmax1.0_Lbolmin44.5: 0.30              225780 vs 324311
# G20.5_zmin0.0zmax1.0_Lbolmin45.0: 0.30              214489 vs 308126
# G20.5_zmin0.0zmax1.0_Lbolmin45.5: 0.31              111779 vs 161096
# G20.5_zmin0.0zmax1.0_Lbolmin46.0: 0.30              17294 vs 24716
# G20.5_zmin0.0zmax1.0_Lbolmin46.5: 0.32              1549 vs 2271

# %%
n_q, n_q_err, V_eff, N_q = [], [], [], []

for j in range(len(L_bol)):
    
    N = len(tab_datahi_mask_zbins[j])
    cp = np.percentile(selfunc_hi_bins[j], mask*100)
    f_sky = 1/(4*np.pi)*np.sum(selfunc_hi_bins[j][selfunc_hi_bins[j]>=cp]*hp.nside2pixarea(NSIDE))
    print(N) # f_sky)
    # zmax = quaia.comoving_dist(1, h = cosmo_planck18['h'], Om0 = cosmo_planck18['Omega_m']) #) cosmos[i]['Omega_m']+cosmos[i]['Omega_c']).value # Mpc/h
    # zmin = quaia.comoving_dist(0, h = cosmo_planck18['h'], Om0 = cosmo_planck18['Omega_m']) #cosmos[i]['Omega_b']+cosmos[i]['Omega_c']).value # Mpc/h
    # V = f_sky*(4/3*np.pi*(zmax**3-zmin**3)) #*cosmo_quaia['h']**3 # convert to 1/Mpc^3
    V = f_sky*(Planck18.comoving_volume(1)-Planck18.comoving_volume(0))*cosmo_planck18['h']**3/u.h**3
    
    N_q.append(N)
    n_q.append(N/V.value)
    n_q_err.append(np.sqrt(N)/V.value) # Poisson error
    V_eff.append(V)
# Out:
# 225780
# 214489
# 111779
# 17294
# 1549

# %%
fduty_err_hi = 0.002, 0.001, 0.008, 0.077
fduty_err_lo = 0.002, 0.001, 0.007, 0.034

# %%
def n_q_theory_err(n_dm, fduty_err, M_min, a, M_min_err, hmf = hmf, cosmo = cosmo_planck18): #quaia):
    
    nm = hmf(cosmo, bins, a)/cosmo['h']**3 # convert to h/Mpc**3
    dn_dm = nm/(bins*np.log(10))
    
    return np.sqrt(n_dm**2*fduty_err**2+(fduty_err*hmf(cosmo, 10**M_min, a))**2*M_min_err**2)

# %% [markdown]
# # Convert to bolometric luminosity
# ## Start with the flux density: $f_{\nu_{\mathrm{G}_{\mathrm{RP}}}}\left[\frac{e^{-}}{s}\right]=10^{-\frac{m_{\mathrm{G}_{\mathrm{RP}, \mathrm{VEG}}}-\mathrm{ZP}_{\mathrm{RP}, \mathrm{VEG}}}{2.5}}$
# ### Load quasars with $z<1.5$

# %%
tab_datahi_mask_zbin0, _, _, _, _, _, selfunc_hi_bin0 = quaia.make_bins(G_hi, [0], False, ['z'], bins = [[0, 1.5]], tab_gcat_type = 'data', method = ['minmax'], fac_rand = 25, n_bins = [None], mask = mask*100, percentile = True, mask_type = None)

# %% [markdown]
# ### Follow https://arxiv.org/abs/2407.21568

# %%
ZP = 24.7479
c_v = 3.299e-36*u.Jy #Jy s/e
f_v = 10**(-(tab_datahi_mask_zbin0['phot_rp_mean_mag'].value-ZP)/2.5)*c_v # convert to Jansky

# %% [markdown]
# ### Chat GPT's suggestion

# %%
f_v_0 = 3040 * u.Jy   # Gaia RP zero point
f_v = f_v_0* 10**(-(tab_datahi_mask_zbin0['phot_rp_mean_mag'].value)/2.5) # convert to Jansky

# %% [markdown]
# ### Try following [Gaia documentation](https://gea.esac.esa.int/archive/documentation/GDR2/Data_processing/chap_cu5pho/sec_cu5pho_calibr/ssec_cu5pho_calibr_extern.html)

# %%
ZP = 24.7619
ZP_AB = 25.1161
I = 10**(-(tab_datahi_mask_zbin0['phot_rp_mean_mag'].value-ZP)/2.5) 
f_v = I*10**(-0.4*(ZP_AB+56.10))* u.Jy

# %% [markdown]
# ### Try following [astropy documentation](https://docs.astropy.org/en/latest/units/logarithmic_units.html)

# %%
ZP = 24.7619
ZP_AB = 25.1161
I = 10**(-(tab_datahi_mask_zbin0['phot_rp_mean_mag'].value-ZP)/2.5) 
G_AB = (-2.5*np.log10(I)+ZP_AB)*u.ABmag

# %%
# lam = 5500 * u.AA
# f_v = G_AB.to(u.erg/u.s/u.cm**2/u.Hz, u.spectral_density(lam))
v_G = 10**14.588*u.Hz # Hz
f_v = G_AB.to(u.erg/u.s/u.cm**2/u.Hz, u.spectral_density(v_G))

# %% [markdown]
# ## Now calculate the intrinsic luminosity: $v_{\mathrm{G}_{\mathrm{RP}}} L_{v_{\mathrm{G}_{\mathrm{RP}}}}=v_{\mathrm{G}_{\mathrm{RP}}} f_{v_{\mathrm{G}_{\mathrm{RP}}}}\left(4 \pi d_{\mathrm{lum}}^2\right)(1+z)^{-0.657}$

# %%
d_L = Planck18.luminosity_distance(tab_datahi_mask_zbin0['redshift_quaia'])
v_G = 10**14.588*u.Hz # Hz
v_G_L_v = v_G*f_v*(4*np.pi*d_L**2)*(1+tab_datahi_mask_zbin0['redshift_quaia'])**(-0.657)

# %% [markdown]
# ## Apply frequency-dependent bolometric correction at $v_{\mathrm{G}_{\mathrm{RP}}}$

# %%
bol_L = v_G_L_v*11.004

# %% [markdown]
# ## Correct according to bolometric luminosity estimates of Wu & Shen (2022)

# %%
bol_L_corrected = bol_L/10**0.073
np.sort(bol_L_corrected.to(u.erg/u.s))
# Out:
# <Quantity [2.51508120e+44, 2.67186129e+44, 2.74632119e+44, ...,
#            1.02574815e+48, 1.06309168e+48, 1.45947736e+48] erg / s>

# %%
import importlib
importlib.reload(quaia)
# Out:
# <module 'quaia' from '/oak/stanford/orgs/kipac/users/mahlet/quaia_bias/scripts/quaia.py'>

# %%
quaia.L_bol(tab_datahi_mask_zbin0)

# %%
tab_datahi_mask_zbin0['L_bol']
# Out:
# <Column name='L_bol' dtype='float64' unit='erg / s' length=667373>
# 1.4047428101389571e+45
#  1.190931469053858e+46
# 3.2476695655546686e+45
#  8.469454598865682e+45
#  9.637005357033347e+45
# 1.5635329421489576e+46
# 1.5652174103891176e+45
#  7.988294789814646e+45
# 1.6037925264838111e+46
# 3.2366687089639643e+45
# 2.0656200274113557e+45
#  6.221252936365188e+45
#                    ...
# 1.9893826553708156e+45
#  3.849957245963082e+45
# 1.4880679437627882e+46
# 1.2081417378734167e+45
#  5.097542836872392e+45
# 1.6423059061132755e+45
# 3.5408138595936604e+45
# 1.3310860933643026e+46
#  7.083281691465465e+45
# 5.2936059299901047e+45
# 1.4643329917499567e+45

# %% [markdown]
# # Perform $\chi^2$ fit
# ## $\chi_c^2=\sum \frac{\left(O_i-E_i\right)^2}{\sigma_i^2}$

# %% [markdown]
# ### Enforce a hard limit on $n_q$

# %%
def f0(x, a, cf_matter, yerr_cf, cf, cosmo = cosmo_planck18): #quaia):
    
    fduty, M_min = x
    
    bins_m = np.logspace(M_min, M_max, 79)
    n_m=np.ones(np.shape(bins_m))*fduty
        
    cf_2h_zbin, b_q = cf_2h(bins_m, n_m, a, cosmo, cf_matter, recenter = False)
    
    return np.sum((cf-cf_2h_zbin)**2/yerr_cf**2)

# %% [markdown]
# ### Add a number density constraint

# %%
def constraint(x, a, n_q, cosmo = cosmo_planck18, error = 0.05):
    
    fduty, M_min = x
    
    bins_m = np.logspace(M_min, M_max, 79)
    n_m=np.ones(np.shape(bins_m))*fduty
    
    n_q_theory = M(bins_m, n_m, a = a, cosmo = cosmo, recenter = False)[1]

    return error-np.abs(n_q_theory-n_q)/n_q

# %% [markdown]
# ## Limit scales to $30\geq s \geq 80h^{-1}$ Mpc

# %% [markdown]
# ### Use the sigma directly

# %%
def f0_GLS(x, a, cf_matter, C, cf, n_q, cosmo = cosmo_planck18, error = 0.05, constraint = True):
    
    fduty, M_min = x
    
    bins_m = np.logspace(M_min, M_max, 79)
    n_m=np.ones(np.shape(bins_m))*fduty
        
    cf_2h_zbin, _ = cf_2h(bins_m, n_m, a, cosmo, cf_matter, recenter = False)

    if constraint == False:
        n_q_theory = M(bins_m, n_m, a = a, cosmo = cosmo, recenter = False)[1]
        penalty = (n_q_theory-n_q)**2/(error*n_q)
    else:
        penalty = 0
        
    return (cf-cf_2h_zbin).T @ np.linalg.inv(C) @ (cf-cf_2h_zbin)+penalty

# %% [markdown]
# ### Use this form of the loss function: $\chi_c^2={\Delta^TC^{-1}}\Delta$

# %%
def f0_GLS_solve(x, a, cf_matter, C, cf, n_q, cosmo = cosmo_planck18):  #quaia):
    
    fduty, M_min = x
    
    bins_m = np.logspace(M_min, M_max, 79)
    n_m=np.ones(np.shape(bins_m))*fduty
        
    cf_2h_zbin, _ = cf_2h(bins_m, n_m, a, cosmo, cf_matter, recenter = False)
    delta = cf-cf_2h_zbin
        
    return delta.T @ np.linalg.solve(C, delta)

# %% [markdown]
# ## Use the full covariance matrix
# ### Include some bins we aren't analyzing

# %%
# Create the bins array
offset = 2.5
delta_max = 40
delta_min = np.min((np.floor((30-0.15)/offset), delta_max))

rmin = 30-delta_min*offset # 0.1 # start higher # 1.4 # 30
rmax = 80+delta_max*offset # 200
nbins = 20 + int(delta_min+delta_max) #90 #20
rbins_chi2 = np.linspace(rmin, rmax, nbins + 1) # Mpc/h https://github.com/manodeep/Corrfunc/issues/202
scale = 'linear'
rbins_chi2, quaia.recenter(rbins_chi2), np.diff(quaia.recenter(rbins_chi2))
# Out:
# (array([  2.5,   5. ,   7.5,  10. ,  12.5,  15. ,  17.5,  20. ,  22.5,
#          25. ,  27.5,  30. ,  32.5,  35. ,  37.5,  40. ,  42.5,  45. ,
#          47.5,  50. ,  52.5,  55. ,  57.5,  60. ,  62.5,  65. ,  67.5,
#          70. ,  72.5,  75. ,  77.5,  80. ,  82.5,  85. ,  87.5,  90. ,
#          92.5,  95. ,  97.5, 100. , 102.5, 105. , 107.5, 110. , 112.5,
#         115. , 117.5, 120. , 122.5, 125. , 127.5, 130. , 132.5, 135. ,
#         137.5, 140. , 142.5, 145. , 147.5, 150. , 152.5, 155. , 157.5,
#         160. , 162.5, 165. , 167.5, 170. , 172.5, 175. , 177.5, 180. ]),
#  array([  3.75,   6.25,   8.75,  11.25,  13.75,  16.25,  18.75,  21.25,
#          23.75,  26.25,  28.75,  31.25,  33.75,  36.25,  38.75,  41.25,
#          43.75,  46.25,  48.75,  51.25,  53.75,  56.25,  58.75,  61.25,
#          63.75,  66.25,  68.75,  71.25,  73.75,  76.25,  78.75,  81.25,
#          83.75,  86.25,  88.75,  91.25,  93.75,  96.25,  98.75, 101.25,
#         103.75, 106.25, 108.75, 111.25, 113.75, 116.25, 118.75, 121.25,
#         123.75, 126.25, 128.75, 131.25, 133.75, 136.25, 138.75, 141.25,
#         143.75, 146.25, 148.75, 151.25, 153.75, 156.25, 158.75, 161.25,
#         163.75, 166.25, 168.75, 171.25, 173.75, 176.25, 178.75]),
#  array([2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5,
#         2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5,
#         2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5,
#         2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5,
#         2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5,
#         2.5, 2.5, 2.5, 2.5, 2.5]))

# %%
cf_chi2, cf_matter_chi2 = [], []
yerr_cf_chi2, b_cf_chi2 = [], []
b_cf_q_chi2 = []
a_zbin = []
H0 = cosmo_planck18['H0'] * u.km/u.s/u.Mpc

for i in range(len(L_bol)):
    
    tab_datahi_mask_zbin0, tab_randhi_mask_zbin0, key_zbin0, _, _, _, selfunc_hi_bin0, _ = quaia.make_bins(G_hi, [0, i], True, ['z', 'L_bol'], 
                                                                                         bins = [zbin_array, L_bol], tab_gcat_type = 'data', 
                                                                                          method = ['minmax', 'threshold'], fac_rand = fac_rand, 
                                                                                          mask = mask*100, percentile = True, n_bins = [None, None])

    # quasar correlation function
    cf, qq, qr = quaia.xi_s(tab_datahi_mask_zbin0, tab_randhi_mask_zbin0, key_zbin0, nthreads = nthreads, 
               rbins = rbins_chi2, Om0 = cosmo_planck18['Omega_m'], h = cosmo_planck18['h'], error = True)
    cf_chi2.append(cf)

    # scale factor
    a = a_median(tab_datahi_mask_zbin0)
    a_zbin.append(a)

    # matter correlation function
    rbins_Mpc = (quaia.recenter(rbins_chi2)*u.Mpc/cu.littleh).to(u.Mpc, cu.with_H0(H0))
    cf_matter = ccl.correlations.correlation_3d(cosmo_planck18, r=rbins_Mpc, a=a)
    cf_matter_chi2.append(cf_matter)

    # effective bias 
    b = np.sqrt(cf/cf_matter)
    b_cf_chi2.append(b)

    # yerr
    yerr=(1+cf)/np.sqrt(qq)
    yerr[cf<0]=np.sqrt((1+b**2*cf_matter)/qr)[cf<0] #https://arxiv.org/abs/1603.04849
    yerr_cf_chi2.append(yerr)

    # qso bias
    b_cf_q_chi2.append(b_qso(cf, cf_matter, ccl.growth_rate(cosmo_planck18, a)))
# Out:
# G20.5_zmin0.0zmax1.0_Lbolmin44.5: 0.30              225780 vs 324311
# /home/groups/tabel/mahlet/pyccl-env/lib/python3.12/site-packages/Corrfunc/utils.py:918: UserWarning: One or more input array has non-native endianness!  A copy will be made with the correct endianness.
#   warnings.warn("One or more input array has non-native endianness!  A copy will"\
# /tmp/ipykernel_20608/2518221395.py:29: RuntimeWarning: invalid value encountered in sqrt
#   b = np.sqrt(cf/cf_matter)
# /tmp/ipykernel_20608/4043121211.py:3: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(xi_qq/xi_mm-4*f**2/45)-f/3
# G20.5_zmin0.0zmax1.0_Lbolmin45.0: 0.30              214489 vs 308126
# /home/groups/tabel/mahlet/pyccl-env/lib/python3.12/site-packages/Corrfunc/utils.py:918: UserWarning: One or more input array has non-native endianness!  A copy will be made with the correct endianness.
#   warnings.warn("One or more input array has non-native endianness!  A copy will"\
# /tmp/ipykernel_20608/2518221395.py:29: RuntimeWarning: invalid value encountered in sqrt
#   b = np.sqrt(cf/cf_matter)
# /tmp/ipykernel_20608/4043121211.py:3: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(xi_qq/xi_mm-4*f**2/45)-f/3
# G20.5_zmin0.0zmax1.0_Lbolmin45.5: 0.31              111779 vs 161096
# /home/groups/tabel/mahlet/pyccl-env/lib/python3.12/site-packages/Corrfunc/utils.py:918: UserWarning: One or more input array has non-native endianness!  A copy will be made with the correct endianness.
#   warnings.warn("One or more input array has non-native endianness!  A copy will"\
# G20.5_zmin0.0zmax1.0_Lbolmin46.0: 0.30              17294 vs 24716
# /tmp/ipykernel_20608/2518221395.py:29: RuntimeWarning: invalid value encountered in sqrt
#   b = np.sqrt(cf/cf_matter)
# /tmp/ipykernel_20608/4043121211.py:3: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(xi_qq/xi_mm-4*f**2/45)-f/3
# /home/groups/tabel/mahlet/pyccl-env/lib/python3.12/site-packages/Corrfunc/utils.py:918: UserWarning: One or more input array has non-native endianness!  A copy will be made with the correct endianness.
#   warnings.warn("One or more input array has non-native endianness!  A copy will"\
# G20.5_zmin0.0zmax1.0_Lbolmin46.5: 0.32              1549 vs 2271
# /tmp/ipykernel_20608/2518221395.py:29: RuntimeWarning: invalid value encountered in sqrt
#   b = np.sqrt(cf/cf_matter)
# /tmp/ipykernel_20608/4043121211.py:3: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(xi_qq/xi_mm-4*f**2/45)-f/3
# /home/groups/tabel/mahlet/pyccl-env/lib/python3.12/site-packages/Corrfunc/utils.py:918: UserWarning: One or more input array has non-native endianness!  A copy will be made with the correct endianness.
#   warnings.warn("One or more input array has non-native endianness!  A copy will"\
# /tmp/ipykernel_20608/2518221395.py:29: RuntimeWarning: invalid value encountered in sqrt
#   b = np.sqrt(cf/cf_matter)
# /tmp/ipykernel_20608/2518221395.py:33: RuntimeWarning: divide by zero encountered in divide
#   yerr=(1+cf)/np.sqrt(qq)
# /tmp/ipykernel_20608/4043121211.py:3: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(xi_qq/xi_mm-4*f**2/45)-f/3

# %%
rpmask = (quaia.recenter(rbins_chi2) >= 30) & (quaia.recenter(rbins_chi2) <= 80)

# %% [markdown]
# ## Solve for $\chi^2=\Delta^T x$ where $Cx=\Delta$

# %%
error = [0.05, 0.05, 0.05, 0.05, 0.05]
res, M_min_fit, fduty_fit = [], [], []
for j in range(len(L_bol)):
    
    C = np.load('../results/cov_xi_G{}_rmin{}_rmax{}_nbins{}_z0.0_Lbolmin{:.1f}_N25_Planck.npy'.format(G_hi, rmin, rmax, nbins, L_bol[j]))
    
    ix_grid = np.ix_(rpmask, rpmask)
    fun = lambda x: f0_GLS_solve(x, a_zbin[j], cf_matter_chi2[j][rpmask], C[ix_grid], cf_chi2[j][rpmask], n_q[j])
    cons = ({'type': 'ineq', 'fun': lambda x: constraint(x, a_zbin[j], n_q[j], error = error[j])}) 
    
    res.append(minimize(fun, [fduty[0], M_min_array[0]], bounds = ((0,1), (9, 15)), constraints = cons, method = 'trust-constr'))
    M_min_fit.append(10**res[j].x[-1])
    fduty_fit.append(res[j].x[0])
    
np.log10(M_min_fit), np.log10(fduty_fit), res
# Out:
# /home/groups/tabel/mahlet/pyccl-env/lib/python3.12/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# (array([12.24371526, 12.421317  , 12.06536209, 12.23360023, 10.86480592]),
#  array([-2.41682726, -2.24830967, -2.86540561, -3.56860644, -6.41511404]),
#  [           message: `xtol` termination condition is satisfied.
#              success: True
#               status: 2
#                  fun: 118.19634078460814
#                    x: [ 3.830e-03  1.224e+01]
#                  nit: 207
#                 nfev: 621
#                 njev: 207
#                 nhev: 0
#             cg_niter: 196
#         cg_stop_cond: 2
#                 grad: [-9.537e-07  1.008e+00]
#      lagrangian_grad: [-3.363e-03  1.700e-01]
#               constr: [array([ 5.000e-02]), array([ 3.830e-03,  1.224e+01])]
#                  jac: [array([[-1.170e+02, -2.360e+00]]), array([[ 1.000e+00,  0.000e+00],
#                              [ 0.000e+00,  1.000e+00]])]
#          constr_nfev: [621, 0]
#          constr_njev: [0, 0]
#          constr_nhev: [0, 0]
#                    v: [array([ 3.388e-01]), array([ 3.964e+01, -3.833e-02])]
#               method: tr_interior_point
#           optimality: 0.17003070416898053
#     constr_violation: 0.0
#       execution_time: 0.5464022159576416
#            tr_radius: 5.3309584335581896e-09
#       constr_penalty: 1.0
#    barrier_parameter: 2.048000000000001e-09
#    barrier_tolerance: 2.048000000000001e-09
#                niter: 207,
#              message: `xtol` termination condition is satisfied.
#              success: True
#               status: 2
#                  fun: 139.23959328908597
#                    x: [ 5.645e-03  1.242e+01]
#                  nit: 71
#                 nfev: 297
#                 njev: 99
#                 nhev: 0
#             cg_niter: 72
#         cg_stop_cond: 4
#                 grad: [ 7.629e-06  4.453e-06]
#      lagrangian_grad: [ 8.707e-09  6.320e-07]
#               constr: [array([ 4.791e-02]), array([ 5.645e-03,  1.242e+01])]
#                  jac: [array([[-1.775e+02,  2.451e+00]]), array([[ 1.000e+00,  0.000e+00],
#                              [ 0.000e+00,  1.000e+00]])]
#          constr_nfev: [297, 0]
#          constr_njev: [0, 0]
#          constr_nhev: [0, 0]
#                    v: [array([-1.498e-06]), array([-2.736e-04, -1.488e-07])]
#               method: tr_interior_point
#           optimality: 6.320073894138074e-07
#     constr_violation: 0.0
#       execution_time: 0.25149035453796387
#            tr_radius: 1.0000000000000005e-09
#       constr_penalty: 1.0
#    barrier_parameter: 2.048000000000001e-09
#    barrier_tolerance: 2.048000000000001e-09
#                niter: 71,
#              message: The maximum number of function evaluations is exceeded.
#              success: False
#               status: 0
#                  fun: 79.83718573655801
#                    x: [ 1.363e-03  1.207e+01]
#                  nit: 1000
#                 nfev: 3000
#                 njev: 1000
#                 nhev: 0
#             cg_niter: 1085
#         cg_stop_cond: 4
#                 grad: [ 9.537e-07  1.311e-02]
#      lagrangian_grad: [ 1.738e-06  6.317e-04]
#               constr: [array([ 4.971e-02]), array([ 1.363e-03,  1.207e+01])]
#                  jac: [array([[ 7.333e+02, -2.353e+00]]), array([[ 1.000e+00,  0.000e+00],
#                              [ 0.000e+00,  1.000e+00]])]
#          constr_nfev: [3000, 0]
#          constr_njev: [0, 0]
#          constr_nhev: [0, 0]
#                    v: [array([ 5.271e-03]), array([-3.865e+00, -8.245e-05])]
#               method: tr_interior_point
#           optimality: 0.0006317016053040653
#     constr_violation: 0.0
#       execution_time: 2.995441198348999
#            tr_radius: 5.235253121878362
#       constr_penalty: 21.97198257411434
#    barrier_parameter: 0.004000000000000001
#    barrier_tolerance: 0.004000000000000001
#                niter: 1000,
#              message: `xtol` termination condition is satisfied.
#              success: True
#               status: 2
#                  fun: 21.517883228243523
#                    x: [ 2.700e-04  1.223e+01]
#                  nit: 324
#                 nfev: 972
#                 njev: 324
#                 nhev: 0
#             cg_niter: 320
#         cg_stop_cond: 2
#                 grad: [ 0.000e+00 -1.350e+00]
#      lagrangian_grad: [-7.319e-04 -1.113e+00]
#               constr: [array([ 4.999e-02]), array([ 2.700e-04,  1.223e+01])]
#                  jac: [array([[-3.703e+03,  2.435e+00]]), array([[ 1.000e+00,  0.000e+00],
#                              [ 0.000e+00,  1.000e+00]])]
#          constr_nfev: [972, 0]
#          constr_njev: [0, 0]
#          constr_nhev: [0, 0]
#                    v: [array([ 4.661e-05]), array([ 1.719e-01,  2.369e-01])]
#               method: tr_interior_point
#           optimality: 1.1132138468686728
#     constr_violation: 0.0
#       execution_time: 0.8514063358306885
#            tr_radius: 5.407404314902385e-09
#       constr_penalty: 1.0
#    barrier_parameter: 2.048000000000001e-09
#    barrier_tolerance: 2.048000000000001e-09
#                niter: 324,
#              message: `xtol` termination condition is satisfied.
#              success: True
#               status: 2
#                  fun: 317.5880028391374
#                    x: [ 3.845e-07  1.086e+01]
#                  nit: 367
#                 nfev: 1101
#                 njev: 367
#                 nhev: 0
#             cg_niter: 355
#         cg_stop_cond: 2
#                 grad: [ 0.000e+00  6.037e-01]
#      lagrangian_grad: [ 3.744e-07  4.579e-01]
#               constr: [array([ 4.777e-02]), array([ 3.845e-07,  1.086e+01])]
#                  jac: [array([[-2.607e+06,  2.131e+00]]), array([[ 1.000e+00,  0.000e+00],
#                              [ 0.000e+00,  1.000e+00]])]
#          constr_nfev: [1101, 0]
#          constr_njev: [0, 0]
#          constr_nhev: [0, 0]
#                    v: [array([-6.450e-11]), array([-1.678e-04, -1.458e-01])]
#               method: tr_interior_point
#           optimality: 0.45794824057508765
#     constr_violation: 0.0
#       execution_time: 0.9753458499908447
#            tr_radius: 5.119261409427282e-09
#       constr_penalty: 1.0
#    barrier_parameter: 2.048000000000001e-09
#    barrier_tolerance: 2.048000000000001e-09
#                niter: 367])

# %%
for j in range(len(L_bol)):
    
    print('L>={} erg/s'.format(L_bol[j]))
    x = fduty_fit[j], np.log10(M_min_fit[j])
    
    C = np.load('../results/cov_xi_G{}_rmin{}_rmax{}_nbins{}_z0.0_Lbolmin{:.1f}_N25_Planck.npy'.format(G_hi, rmin, rmax, nbins, L_bol[j]))
    ix_grid = np.ix_(rpmask, rpmask)
    chi2 = f0_GLS_solve(x, a_zbin[j], cf_matter_chi2[j][rpmask], C[ix_grid], cf_chi2[j][rpmask], n_q[j])
    df = nbins-len(x)
    
    print('           chi^2: {:.2f}'.format(chi2))
    print('   reduced chi^2: {:.2f}'.format(chi2/df))
    print('         delta n: {:.2e}'.format(constraint(x, a_zbin[j], n_q[j], error = error[j])))
    print('condition number: {:.2f}'.format(np.linalg.cond(C)))
    print('             PTE: {:.2e}\n'.format(stats.chi2.sf(chi2, df)))
# Out:
# L>=44.5 erg/s
#            chi^2: 118.20
#    reduced chi^2: 1.71
#          delta n: 5.00e-02
# condition number: 134792852686848311296.00
#              PTE: 2.11e-04
#
# L>=45.0 erg/s
#            chi^2: 139.24
#    reduced chi^2: 2.02
#          delta n: 4.79e-02
# condition number: 37630326030582431744.00
#              PTE: 1.17e-06
#
# L>=45.5 erg/s
#            chi^2: 79.84
#    reduced chi^2: 1.16
#          delta n: 4.97e-02
# condition number: 251004634542490681344.00
#              PTE: 1.75e-01
#
# L>=46.0 erg/s
#            chi^2: 21.52
#    reduced chi^2: 0.31
#          delta n: 5.00e-02
# condition number: 123364612420862066688.00
#              PTE: 1.00e+00
#
# L>=46.5 erg/s
#            chi^2: 317.59
#    reduced chi^2: 4.60
#          delta n: 4.78e-02
# condition number: 16164615762696488960.00
#              PTE: 1.46e-33

# %%
fduty_array = np.logspace(-5,0, 51) #-4

# %%
chi2_grid = {j: np.zeros((len(bins), len(fduty_array))) for j in range(len(L_bol))}
cons_grid = {j: np.zeros((len(bins), len(fduty_array))) for j in range(len(L_bol))}
for j in range(len(L_bol)):

    for k in range(len(fduty_array)):
        
        for l in range(len(bins)):
            
            x = fduty_array[k], np.log10(bins[l])

            C = np.load('../results/cov_xi_G{}_rmin{}_rmax{}_nbins{}_z0.0_Lbolmin{:.1f}_N25_Planck.npy'.format(G_hi, rmin, rmax, nbins, L_bol[j]))
            ix_grid = np.ix_(rpmask, rpmask)

            chi2_m = f0_GLS_solve(x, a_zbin[j], cf_matter_chi2[j][rpmask], C[ix_grid], cf_chi2[j][rpmask], n_q[j])
            chi2_grid[j][l,k]=chi2_m
            cons = constraint(x, a_zbin[j], n_q[j], error = error[j])
            cons_grid[j][l,k]=cons
# Out:
# /tmp/ipykernel_20608/2313523635.py:30: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1/n_g*np.trapz(integrand*b, bins)
# /tmp/ipykernel_20608/2313523635.py:30: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1/n_g*np.trapz(integrand*b, bins)

# %%
cmap_chi2 = sns.cubehelix_palette(start=2, rot=0, dark=0, light=1, as_cmap=True)
cmap_chi2

# %%
cmap_fduty = sns.color_palette("mako", n_colors = len(fduty_array))
palette_fduty = matplotlib.colors.ListedColormap(cmap_fduty)
palette_fduty

# %%
fig = plt.figure(figsize = (20, 40))
gs = gridspec.GridSpec(5, 2, hspace = 0.15, wspace = 0.1)

for j in range(len(L_bol)):
    
    ax1 = fig.add_subplot(gs[j*2])
    image = ax1.imshow(np.log10(chi2_grid[j]), cmap = cmap_chi2, vmin = np.log10(50.13706414974333), vmax = np.log10(3216118165719.2197), extent =  [np.log10(fduty_array[0]), np.log10(fduty_array[-1]), np.log10(bins[0]), np.log10(bins[-1])], aspect = 'auto', origin = 'lower')
    ax1.set_title('$L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(L_bol[j]))
    if j == 4:
        ax1.set_xlabel('$\log_{10} (f_{duty})$')
    ax1.set_ylabel('$\log_{10} (M_{min}/M_\odot)$')
    fig.colorbar(image, label='$\log_{10} (\chi^2)$')
    ax1.axhline(np.log10(M_min_fit[j]), color = 'red', linestyle = '--')
    ax1.axvline(np.log10(fduty_fit[j]), color = 'red', linestyle = '--')
    
    ax1 = fig.add_subplot(gs[j*2+1])
    image = ax1.imshow(cons_grid[j], cmap = palette_fduty, norm = 'symlog', vmin = -4348491.828200184, vmax = 0.09959201649593023, extent = [np.log10(fduty_array[0]), np.log10(fduty_array[-1]), np.log10(bins[0]), np.log10(bins[-1])], aspect = 'auto', origin = 'lower')
    ax1.set_title('$L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(L_bol[j]))
    if j == 4:
        ax1.set_xlabel('$\log_{10} (f_{duty})$')
    fig.colorbar(image, label='$\Delta n_q$')
    ax1.axhline(np.log10(M_min_fit[j]), color = 'red', linestyle = '--')
    ax1.axvline(np.log10(fduty_fit[j]), color = 'red', linestyle = '--')

plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\l'
# <>:11: SyntaxWarning: invalid escape sequence '\l'
# <>:12: SyntaxWarning: invalid escape sequence '\l'
# <>:18: SyntaxWarning: invalid escape sequence '\m'
# <>:20: SyntaxWarning: invalid escape sequence '\l'
# <>:21: SyntaxWarning: invalid escape sequence '\D'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\l'
# <>:11: SyntaxWarning: invalid escape sequence '\l'
# <>:12: SyntaxWarning: invalid escape sequence '\l'
# <>:18: SyntaxWarning: invalid escape sequence '\m'
# <>:20: SyntaxWarning: invalid escape sequence '\l'
# <>:21: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_20608/676983591.py:8: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_title('$L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(L_bol[j]))
# /tmp/ipykernel_20608/676983591.py:10: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10} (f_{duty})$')
# /tmp/ipykernel_20608/676983591.py:11: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_ylabel('$\log_{10} (M_{min}/M_\odot)$')
# /tmp/ipykernel_20608/676983591.py:12: SyntaxWarning: invalid escape sequence '\l'
#   fig.colorbar(image, label='$\log_{10} (\chi^2)$')
# /tmp/ipykernel_20608/676983591.py:18: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_title('$L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(L_bol[j]))
# /tmp/ipykernel_20608/676983591.py:20: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10} (f_{duty})$')
# /tmp/ipykernel_20608/676983591.py:21: SyntaxWarning: invalid escape sequence '\D'
#   fig.colorbar(image, label='$\Delta n_q$')

# %% [markdown]
# ## Plot results

# %%
zbin = 1/np.array(a_zbin)-1

# %%
plt.plot(L_bol, np.log10(M_min_fit), color = 'darkblue', linewidth = 2.5, label = 'Shiferaw et al. 2026 (this work)')
plt.axhline(M_min_array[0], label = 'Giner Mascarell et al. 2025', color = 'lightgreen', linewidth = 2.5, linestyle = '--')
plt.ylabel('$\log_{10}(M_{min}/M_\odot)$')
plt.xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
plt.legend(bbox_to_anchor = (0.5, -0.2), loc='upper center')
plt.xlim(L_bol[0], L_bol[-1])
plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\l'
# <>:4: SyntaxWarning: invalid escape sequence '\l'
# <>:3: SyntaxWarning: invalid escape sequence '\l'
# <>:4: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_20608/3432766316.py:3: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel('$\log_{10}(M_{min}/M_\odot)$')
# /tmp/ipykernel_20608/3432766316.py:4: SyntaxWarning: invalid escape sequence '\l'
#   plt.xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')

# %%
plt.plot(L_bol, np.log10(fduty_fit), color = 'darkblue', linewidth = 2.5, label = 'Shiferaw et al. 2026 (this work)')
plt.fill_between(L_bol, [np.log10(fduty[0]+fduty_err_hi[0])]*len(L_bol), [np.log10(fduty[0]-fduty_err_lo[0])]*len(L_bol), alpha = 0.5, 
                 color = 'lightgreen')
plt.axhline(np.log10(fduty[0]), label = 'Giner Mascarell et al. 2025', color = 'lightgreen', linewidth = 2.5, linestyle = '--')
plt.ylabel('$\log_{10}(f_{duty})$')
plt.xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
plt.legend(bbox_to_anchor = (0.5, -0.2), loc='upper center')
plt.xlim(L_bol[0], L_bol[-1])
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\l'
# <>:6: SyntaxWarning: invalid escape sequence '\l'
# <>:5: SyntaxWarning: invalid escape sequence '\l'
# <>:6: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_20608/1055270469.py:5: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel('$\log_{10}(f_{duty})$')
# /tmp/ipykernel_20608/1055270469.py:6: SyntaxWarning: invalid escape sequence '\l'
#   plt.xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')

# %%
b_eff_cf20 = np.load('../results/b_eff_cf20_planck18.npy')

# %% [markdown]
# ## Pick cosmology

# %%
cosmo = 'Planck'

# %%
# plot!
fig = plt.figure(figsize = (24,16))  #13.5
grid = gridspec.GridSpec(5, 6, height_ratios = [1, 0.5, 0.35, 1, 0.5], hspace = 0) #0.25

ax1 = plt.subplot(grid[0, 0:2])
ax2 = plt.subplot(grid[0, 2:4])
ax3 = plt.subplot(grid[0, 4:6])
ax4 = plt.subplot(grid[3, 1:3])
ax5 = plt.subplot(grid[3, 3:5])
axlist = [ax1, ax2, ax3, ax4, ax5] #https://www.geeksforgeeks.org/matplotlib-gridspec-gridspec-class-in-python/

ax6 = plt.subplot(grid[1, 0:2])
ax7 = plt.subplot(grid[1, 2:4])
ax8 = plt.subplot(grid[1, 4:6])
ax9 = plt.subplot(grid[4, 1:3])
ax10 = plt.subplot(grid[4, 3:5])
axlist2 = [ax6, ax7, ax8, ax9, ax10] #https://www.geeksforgeeks.org/matplotlib-gridspec-gridspec-class-in-python/

# fig = plt.figure(figsize = (20, 24))
# gs = gridspec.GridSpec(5, 2, height_ratios = [1, 0.5, 0.15, 1, 0.5], hspace = 0, wspace = 0)

ylim = 2e-6, 4
k = 0
for j in range(len(L_bol)):

    ax1 = axlist[j]
    ax2 = axlist2[j]
    
    C = np.load('../results/cov_xi_G{}_rmin{}_rmax{}_nbins{}_z0.0_Lbolmin{:.1f}_N25_Planck.npy'.format(G_hi, rmin, rmax, nbins, L_bol[j]))
            
    ax1.errorbar(quaia.recenter(rbins_chi2), cf_chi2[j], linewidth = 2.5, marker = 'o', 
                 # label = r'Quaia',
                 color = 'red',
                yerr = np.sqrt(np.diag(C)), markeredgewidth = 2.5, capsize = 2.5, linestyle = 'none')
    ax1.plot(quaia.recenter(rbins_chi2), b_eff_cf20[0]**2*cf_matter_chi2[j], linewidth = 2.5,
             # label = r'${b_{eff, 20}}^2\xi_m$', 
             color = 'orange', linestyle = '--')
    ax1.fill_betweenx(np.linspace(ylim[0], ylim[1]), x1 = quaia.recenter(rbins_chi2)[0], x2 = 30, color = 'grey', 
                      alpha = 0.5) # label = 'scales excluded from fit')
    ax1.fill_betweenx(np.linspace(ylim[0], ylim[1]), x1 = 80, x2 = quaia.recenter(rbins_chi2)[-1], color = 'grey', 
                      alpha = 0.5)

    # old fit
    cf_2h_zbin, b_q = cf_2h(bins_M_min[j], n_m_array[j], a_zbin[j], cosmo_planck18, cf_matter_chi2[j], recenter = False)
    ax1.plot(quaia.recenter(rbins_chi2), cf_2h_zbin, linewidth = 2.5, 
             # label = r'$\xi_{{q,2h}}(f_{{duty}}=10^{{{:.2f}}}, M_{{min}}=10^{{{:.2f}}}M_\odot)$'.format(np.log10(fduty[0]), M_min_array[0]),
             color = 'lightgreen')
    ax2.axhline(b_q, linewidth = 2.5, color = 'lightgreen')

    # plot new fit
    n_m=np.ones(np.shape(bins))*fduty_fit[j]
    cf_2h_zbin, b_q = cf_2h(np.logspace(np.log10(M_min_fit[j]),M_max,79), n_m, a_zbin[j], cosmo_planck18, cf_matter_chi2[j], 
                            recenter = False)
    ax1.plot(quaia.recenter(rbins_chi2), cf_2h_zbin, linewidth = 2.5,
             label = r'$\xi_{{q,2h}}(f_{{duty}}=10^{{{:.2f}}}, M_{{min}}=10^{{{:.2f}}}M_\odot)$'.format(np.log10(fduty_fit[j]), 
                                                                                                        np.log10(M_min_fit[j])), 
             color = 'darkblue')
    ax1.plot(quaia.recenter(rbins_chi2), cf_matter_chi2[j], linewidth = 1, linestyle = '--', color = 'green')
    ax2.axhline(b_q, linewidth = 2.5, color = 'darkblue')

    ax2.errorbar(quaia.recenter(rbins_chi2), b_cf_chi2[j], linewidth = 2.5, linestyle = '--', markeredgewidth = 2.5, capsize = 2.5,
                 color = 'purple', yerr = np.sqrt(np.diag(C)), label = '$b_{eff}(s)$')
    ax2.axhline(b_eff_cf20[0], linewidth = 2.5, color = 'orange', linestyle = '--')
    ax2.fill_betweenx(np.linspace(0, 10), x1 = quaia.recenter(rbins_chi2)[0], x2 = 30, color = 'grey', 
                      alpha = 0.5)
    ax2.fill_betweenx(np.linspace(0, 10), x1 = 80, x2 = quaia.recenter(rbins_chi2)[-1], color = 'grey', 
                      alpha = 0.5)
    
    # if (j + k) % 6 < 2:
    ax1.set_title('$G<{}: L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(G_hi, L_bol[j]))
    ax1.set_yscale('log')
    ax1.set_xlim(quaia.recenter(rbins_chi2)[0], quaia.recenter(rbins_chi2)[-1])
    ax1.set_xticklabels([])
    ax1.set_ylim(ylim)
    ax1.legend()

    # ax2.axhline(1, linestyle = '-.', color = 'black', alpha = 0.5)
    ax2.set_xlim(quaia.recenter(rbins_chi2)[0], quaia.recenter(rbins_chi2)[-1])
    ax2.set_ylim(0, 10)
    
    if (j == 0) or (j == 3):
        ax1.set_ylabel(r'$\xi(s)$')
        ax2.set_ylabel(r'$b(s)$')

    else:
        ax1.set_yticklabels([])
        ax2.set_yticklabels([])

    # if k != 0:
    ax2.set_xlabel(r'$s$ $[h^{-1}$ Mpc]') # 
            
    if j % 2 != 0:
        k+=4

custom_lines = [Line2D([0], [0], color = 'orange', linestyle = '--', linewidth = 2.5),
                mpatches.Patch(color='grey', alpha = 0.5),
                Line2D([0], [0], color = 'lightgreen', linestyle = '-', linewidth = 2.5),
                Line2D([0], [0], color = 'green', linestyle = '--', linewidth = 1), 
                Line2D([0], [0], color = 'red', linestyle = 'none', marker = 'o', linewidth = 2.5)]
second_legend = ax2.legend(custom_lines, [r'${b_{eff, 20}}^2\xi_m$', 'scales excluded from fit', 
                                          r'$\xi_{{q,2h}}(f_{{duty}}=10^{{{:.2f}}}, M_{{min}}=10^{{{:.2f}}}M_\odot)$'.format(np.log10(fduty[0]), 
                                                                                                                             M_min_array[0]), r'$\xi_{{m,2h}}$',
                                          r'Quaia'], bbox_to_anchor = (1.5, 2.1), loc='upper center')
fig.add_artist(second_legend)

ax2.legend()

plt.show()
# Out:
# <>:70: SyntaxWarning: invalid escape sequence '\m'
# <>:70: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_20608/2465259990.py:70: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_title('$G<{}: L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(G_hi, L_bol[j]))

# %%
# plot!
fig = plt.figure(figsize = (24,11))  #13.5
grid = gridspec.GridSpec(2, 6, hspace = 0.35) #0.25

ax1 = plt.subplot(grid[0, 0:2])
ax2 = plt.subplot(grid[0, 2:4])
ax3 = plt.subplot(grid[0, 4:6])
ax4 = plt.subplot(grid[1, 1:3])
ax5 = plt.subplot(grid[1, 3:5])
axlist = [ax1, ax2, ax3, ax4, ax5] #https://www.geeksforgeeks.org/matplotlib-gridspec-gridspec-class-in-python/

ylim = 2e-6, 4
k = 0
for j in range(len(L_bol)):

    ax1 = axlist[j]
    
    C = np.load('../results/cov_xi_G{}_rmin{}_rmax{}_nbins{}_z0.0_Lbolmin{:.1f}_N25_Planck.npy'.format(G_hi, rmin, rmax, nbins, L_bol[j]))
            
    ax1.errorbar(quaia.recenter(rbins_chi2), cf_chi2[j], linewidth = 2.5, marker = 'o', 
                 # label = r'Quaia', 
                 color = 'red',
                yerr = np.sqrt(np.diag(C)), markeredgewidth = 2.5, capsize = 2.5, linestyle = 'none')
    ax1.fill_betweenx(np.linspace(ylim[0], ylim[1]), x1 = quaia.recenter(rbins_chi2)[0], x2 = 30, color = 'grey', 
                      alpha = 0.5)#, label = 'scales excluded from fit')
    ax1.fill_betweenx(np.linspace(ylim[0], ylim[1]), x1 = 80, x2 = quaia.recenter(rbins_chi2)[-1], color = 'grey', 
                      alpha = 0.5)

    # plot new fit
    n_m=np.ones(np.shape(bins))*fduty_fit[j]
    cf_2h_zbin, b_q = cf_2h(np.logspace(np.log10(M_min_fit[j]),M_max,79), n_m, a_zbin[j], cosmo_planck18, cf_matter_chi2[j], 
                            recenter = False)
    ax1.plot(quaia.recenter(rbins_chi2), cf_2h_zbin, linewidth = 2.5,
             label = r'$\xi_{{q,2h}}(f_{{duty}}=10^{{{:.2f}}}, M_{{min}}=10^{{{:.2f}}}M_\odot)$'.format(np.log10(fduty_fit[j]), 
                                                                                                        np.log10(M_min_fit[j])), 
             color = 'darkblue')

    # if j % 6 < 2:
    ax1.set_title('$G<{}: L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(G_hi, L_bol[j]))
    ax1.set_yscale('log')
    ax1.set_xlim(quaia.recenter(rbins_chi2)[0], quaia.recenter(rbins_chi2)[-1])
    ax1.set_ylim(ylim)
    
    if (j == 0) or (j == 3):
        ax1.set_ylabel(r'$\xi(s)$')

    else:
        ax1.set_yticklabels([])

    # if j > 1:
    ax1.set_xlabel(r'$s$ $[h^{-1}$ Mpc]') # 
            
    if j % 2 != 0:
        k+=2

    if j == 4:
        custom_lines = [mpatches.Patch(color='grey', alpha = 0.5),
                        Line2D([0], [0], color = 'red', linestyle = 'none', marker = 'o', linewidth = 2.5)]
        second_legend = ax1.legend(custom_lines, ['scales excluded from fit', r'Quaia'], bbox_to_anchor = (1.35, 0.3), loc='upper center')
        fig.add_artist(second_legend)

    ax1.legend()


plt.show()
# Out:
# <>:39: SyntaxWarning: invalid escape sequence '\m'
# <>:39: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_20608/2785666152.py:39: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_title('$G<{}: L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(G_hi, L_bol[j]))

# %%
cmap_M_min = sns.color_palette("vlag", n_colors = len(bins))
palette_M_min = matplotlib.colors.ListedColormap(cmap_M_min)
palette_M_min

# %%
fig = plt.figure(figsize = (10, 8))
labels_cf = ['qq', r'$\xi_{2h}$']
gs = gridspec.GridSpec(1, 3, width_ratios = [1, 0.05, 0.05], wspace = 0)
ax1 = fig.add_subplot(gs[0])
    
b_q = [cf_2h(bins_M_min[j], n_m_array[j], a_zbin[j], cosmo_planck18, cf_chi2[j], 
             recenter = False)[1] for j in range(len(L_bol))]
ax1.plot(L_bol, b_q, linewidth = 2.5, color = 'lightgreen', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))

b_q = [cf_2h(np.logspace(np.log10(M_min_fit[j]), M_max, 79), np.ones(np.shape(bins))*fduty_fit[j], a_zbin[j], cosmo_planck18, 
             cf_chi2[j], recenter = False)[1] for j in range(len(L_bol))]
ax1.plot(L_bol, b_q, linewidth = 2.5, color = 'darkblue', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))

for k in range(len(bins)):
    b_q = [cf_2h(np.logspace(np.log10(M_min_fit[j])-1+k/int(len(bins)/2), M_max, 79), np.ones(np.shape(bins))*fduty_fit[j], a_zbin[j], 
                 cosmo_planck18, cf_chi2[j], recenter = False)[1] for j in range(len(L_bol))]
    ax1.plot(L_bol, b_q, linewidth = 2.5, color = cmap_M_min[k], zorder = 0) # color = cmaps[i][j], alpha = (l+1)/len(bins))

ax1.plot(L_bol, b_quaia(1.26, a_zbin), linestyle = '-.', linewidth = 2.5, 
         label = 'Piccirilli et al. 2024 (GMV)', color = 'green') # eq 3.6 in https://arxiv.org/abs/2402.05761
ax1.plot(L_bol, b_quaia(1.15, a_zbin), linestyle = '-.', linewidth = 2.5, 
         label = 'Piccirilli et al. 2024 (No-TT)', color = 'purple') # eq 3.6 in https://arxiv.org/abs/2402.05761
ax1.plot(L_bol, b_eboss(zbin), linestyle = '--', linewidth = 2.5, label = 'Laurent et al. 2017', 
         color = 'black') # eq 3.6 in https://arxiv.org/abs/2402.05761

ax1.axhline(b_cf20[0], linestyle = ':', linewidth = 2.5, label = r'$b_{\xi, 20}$', color = 'orange') 
ax1.axhline(b_wp20[0], linestyle = ':', linewidth = 2.5, label = '$b_{w_p, 20}$', color = 'red') 

ax1.set_title('$G<{}$'.format(G_hi))

ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
# ax1.set_ylim(0, 10)
ax1.set_xlim(L_bol[0], L_bol[-1])
ax1.set_ylabel(r'$b_q$')

custom_lines = [Line2D([0], [0], color = 'lightgreen', linestyle = ':', linewidth = 2.5),
                Line2D([0], [0], color = 'darkblue', linestyle = ':', linewidth = 2.5),
                Line2D([0], [0], color = 'green', linestyle = '-.', linewidth = 2.5), 
                Line2D([0], [0], color = 'purple', linestyle = '-.', linewidth = 2.5),
                Line2D([0], [0], color = 'black', linestyle = '--', linewidth = 2.5), 
                Line2D([0], [0], color = 'orange', linestyle = ':', linewidth = 2.5), 
                Line2D([0], [0], color = 'red', linestyle = ':', linewidth = 2.5)]
second_legend = ax1.legend(custom_lines, [r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0]), 
                                          '$\chi^2$ minimization', 'Piccirilli et al. 2024 (GMV)', 'Piccirilli et al. 2024 (No-TT)', 
                                          'Laurent et al. 2017', r'$b_{\xi, 20}$', '$b_{w_p, 20}$'], ncol = 2, bbox_to_anchor = (0.5, -0.15), 
                           loc='upper center')
fig.add_artist(second_legend)

cbar = fig.colorbar(cm.ScalarMappable(cmap=palette_M_min, norm = matplotlib.colors.Normalize(vmin=-1, vmax = 1)), cax = fig.add_subplot(gs[:,-1]), 
                    label = '$\Delta \log_{10}(M_{min}/M_\odot)$')
plt.show()
# Out:
# <>:31: SyntaxWarning: invalid escape sequence '\l'
# <>:44: SyntaxWarning: invalid escape sequence '\c'
# <>:50: SyntaxWarning: invalid escape sequence '\D'
# <>:31: SyntaxWarning: invalid escape sequence '\l'
# <>:44: SyntaxWarning: invalid escape sequence '\c'
# <>:50: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_20608/3708366384.py:31: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
# /tmp/ipykernel_20608/3708366384.py:44: SyntaxWarning: invalid escape sequence '\c'
#   '$\chi^2$ minimization', 'Piccirilli et al. 2024 (GMV)', 'Piccirilli et al. 2024 (No-TT)',
# /tmp/ipykernel_20608/3708366384.py:50: SyntaxWarning: invalid escape sequence '\D'
#   label = '$\Delta \log_{10}(M_{min}/M_\odot)$')

# %%
fig = plt.figure(figsize = (10, 8))
labels_cf = ['qq', r'$\xi_{2h}$']
gs = gridspec.GridSpec(1, 1, wspace = 0)
ax1 = fig.add_subplot(gs[0])
    
M_h = [M(bins_M_min[j], n_m_array[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[0] for j in range(len(L_bol))]
ax1.plot(L_bol, np.log10(M_h), linewidth = 2.5, color = 'lightgreen', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))

M_h = [M(np.logspace(np.log10(M_min_fit[j]), M_max, 79), np.ones(np.shape(bins))*fduty_fit[j], a = a_zbin[j], cosmo = cosmo_planck18, 
         recenter = False)[0] for j in range(len(L_bol))]
ax1.plot(L_bol, np.log10(M_h), linewidth = 2.5, color = 'darkblue', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))

# z = np.linspace(0.8, 2.25)
ax1.fill_between(L_bol, [np.log10(1e12/cosmo_planck18['h'])]*len(L_bol), [np.log10(3e12/cosmo_planck18['h'])]*len(L_bol), alpha = 0.5, 
                 label = 'Chehade et al. 2016', color = 'red')
ax1.set_title('$G<{}$'.format(G_hi))
ax1.fill_between(L_bol, [np.log10(1.6e12/cosmo_planck18['h'])]*len(L_bol), [np.log10(4e12/cosmo_planck18['h'])]*len(L_bol), linewidth = 2.5, 
                 label = 'Eltvedt et al. 2024 (HOD)', alpha = 0.5, color = 'orange')
ax1.fill_between(L_bol, [13.47]*len(L_bol), [13.49]*len(L_bol), alpha = 0.5, label = 'Cordova et al. 2025 (Type I)', color = 'green')

# check redshift range and check cordova type i was right to include because conflicts with this
ax1.fill_between(L_bol, [np.log10(10**12.53/cosmo_planck18['h'])]*len(L_bol), [np.log10(10**12.62/cosmo_planck18['h'])]*len(L_bol), alpha = 0.5, 
                 label = 'Petter et al. 2023 (unobscured)', color = 'blue')

custom_lines = [Line2D([0], [0], color = 'lightgreen', linestyle = ':', linewidth = 2.5), Line2D([0], [0], color = 'darkblue', linestyle = ':', linewidth = 2.5), mpatches.Patch(color='red', alpha = 0.5), 
                mpatches.Patch(color='orange', alpha = 0.5), mpatches.Patch(color='green', alpha = 0.5), mpatches.Patch(color='blue', alpha = 0.5)]
second_legend = ax1.legend(custom_lines, [r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0]), '$\chi^2$ minimization',
                            'Chehade et al. 2016', 'Eltvedt et al. 2024 (HOD)', 'Cordova et al. 2025 (Type I)', 'Petter et al. 2023 (unobscured)'], 
                           ncol = 2, bbox_to_anchor = (0.5, -0.15), loc='upper center')
fig.add_artist(second_legend)

ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')

ax1.set_ylabel(r'log$_{10}(\langle M \rangle/M_\odot)$')
ax1.set_xlim(L_bol[0], L_bol[-1])
ax1.set_ylim(12.1, 13.5)

plt.show()
# Out:
# <>:27: SyntaxWarning: invalid escape sequence '\c'
# <>:32: SyntaxWarning: invalid escape sequence '\l'
# <>:27: SyntaxWarning: invalid escape sequence '\c'
# <>:32: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_20608/116917844.py:27: SyntaxWarning: invalid escape sequence '\c'
#   second_legend = ax1.legend(custom_lines, [r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0]), '$\chi^2$ minimization',
# /tmp/ipykernel_20608/116917844.py:32: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')

# %%
fig = plt.figure(figsize = (10, 8))
labels_cf = ['qq', r'$\xi_{2h}$']
gs = gridspec.GridSpec(1, 3, width_ratios = [1, 0.05, 0.05], wspace = 0)
ax1 = fig.add_subplot(gs[0])

for k in range(len(bins)):
    
    M_h = [M(bins_M_min_array[k], n_m_array_2D[j][k], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[0] for j in range(len(L_bol))]
    ax1.plot(L_bol, np.log10(M_h), linewidth = 2.5, 
             label = r'$f_{{duty}}: {:.2f}\%-{:.2f}\%, M_{{min}}:{:.2f} M_\odot$'.format(fduty[0]*100, fduty[-1]*100, np.log10(bins[k])),
             color = cmap[k]) #, alpha = (1+k)/len(bins))
    
M_h = [M(bins_M_min[j], n_m_array[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[0] for j in range(len(L_bol))]
ax1.plot(L_bol, np.log10(M_h), linewidth = 2.5, color = 'lightgreen', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))

M_h = [M(np.logspace(np.log10(M_min_fit[j]), M_max, 79), np.ones(np.shape(bins))*fduty_fit[j], a = a_zbin[j], cosmo = cosmo_planck18, 
         recenter = False)[0] for j in range(len(L_bol))]
ax1.plot(L_bol, np.log10(M_h), linewidth = 2.5, color = 'darkblue', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))

# z = np.linspace(0.8, 2.25)
ax1.fill_between(L_bol, [np.log10(1e12/cosmo_planck18['h'])]*len(L_bol), [np.log10(3e12/cosmo_planck18['h'])]*len(L_bol), alpha = 0.5, 
                 label = 'Chehade et al. 2016', color = 'red')
ax1.set_title('$G<{}$'.format(G_hi))
ax1.fill_between(L_bol, [np.log10(1.6e12/cosmo_planck18['h'])]*len(L_bol), [np.log10(4e12/cosmo_planck18['h'])]*len(L_bol), linewidth = 2.5, 
                 label = 'Eltvedt et al. 2024 (HOD)', alpha = 0.5, color = 'orange')
ax1.fill_between(L_bol, [13.47]*len(L_bol), [13.49]*len(L_bol), alpha = 0.5, label = 'Cordova et al. 2025 (Type I)', color = 'green')

# check redshift range and check cordova type i was right to include because conflicts with this
ax1.fill_between(L_bol, [np.log10(10**12.53/cosmo_planck18['h'])]*len(L_bol), [np.log10(10**12.62/cosmo_planck18['h'])]*len(L_bol), alpha = 0.5, 
                 label = 'Petter et al. 2023 (unobscured)', color = 'blue')

custom_lines = [Line2D([0], [0], color = 'lightgreen', linestyle = ':', linewidth = 2.5), Line2D([0], [0], color = 'darkblue', linestyle = ':', linewidth = 2.5), mpatches.Patch(color='red', alpha = 0.5), 
                mpatches.Patch(color='orange', alpha = 0.5), mpatches.Patch(color='green', alpha = 0.5), mpatches.Patch(color='blue', alpha = 0.5)]
second_legend = ax1.legend(custom_lines, [r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0]), '$\chi^2$ minimization',
                            'Chehade et al. 2016', 'Eltvedt et al. 2024 (HOD)', 'Cordova et al. 2025 (Type I)', 'Petter et al. 2023 (unobscured)'], 
                           ncol = 2, bbox_to_anchor = (0.5, -0.15), loc='upper center')
fig.add_artist(second_legend)

ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')

ax1.set_ylabel(r'log$_{10}(\langle M \rangle/M_\odot)$')
ax1.set_xlim(L_bol[0], L_bol[-1])
ax1.set_ylim(12.1, 13.5)

cbar = fig.colorbar(cm.ScalarMappable(cmap=palette, norm = matplotlib.colors.LogNorm(vmin=bins[0], vmax = bins[-1])), cax = fig.add_subplot(gs[:,-1]), label = '$M_{min}[M_\odot]$')
plt.show()
# Out:
# <>:34: SyntaxWarning: invalid escape sequence '\c'
# <>:39: SyntaxWarning: invalid escape sequence '\l'
# <>:45: SyntaxWarning: invalid escape sequence '\o'
# <>:34: SyntaxWarning: invalid escape sequence '\c'
# <>:39: SyntaxWarning: invalid escape sequence '\l'
# <>:45: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_20608/559478700.py:34: SyntaxWarning: invalid escape sequence '\c'
#   second_legend = ax1.legend(custom_lines, [r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0]), '$\chi^2$ minimization',
# /tmp/ipykernel_20608/559478700.py:39: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
# /tmp/ipykernel_20608/559478700.py:45: SyntaxWarning: invalid escape sequence '\o'
#   cbar = fig.colorbar(cm.ScalarMappable(cmap=palette, norm = matplotlib.colors.LogNorm(vmin=bins[0], vmax = bins[-1])), cax = fig.add_subplot(gs[:,-1]), label = '$M_{min}[M_\odot]$')
# /tmp/ipykernel_20608/2313523635.py:30: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1/n_g*np.trapz(integrand*b, bins)
# /tmp/ipykernel_20608/2313523635.py:30: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1/n_g*np.trapz(integrand*b, bins)

# %%
fig = plt.figure(figsize = (10, 8))
labels_cf = ['qq', r'$\xi_{2h}$']
gs = gridspec.GridSpec(1, 3, width_ratios = [1, 0.05, 0.05], wspace = 0)
ax1 = fig.add_subplot(gs[0])

for k in range(len(bins)):
    
    M_h = [M(np.logspace(np.log10(M_min_fit[j])-1+k/int(len(bins)/2), M_max, 79), np.ones(np.shape(bins))*fduty_fit[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[0] for j in range(len(L_bol))]
    ax1.plot(L_bol, np.log10(M_h), linewidth = 2.5, 
             label = r'$f_{{duty}}: {:.2f}\%-{:.2f}\%, M_{{min}}:{:.2f} M_\odot$'.format(fduty[0]*100, fduty[-1]*100, np.log10(bins[k])),
             color = cmap_M_min[k], zorder = 0) #, alpha = (1+k)/len(bins))
    
# for k in range(len(bins)):
#     b_q = [cf_2h(np.logspace(np.log10(M_min_fit[j])-1+k/int(len(bins)/2), M_max, 79), np.ones(np.shape(bins))*fduty_fit[j], a_zbin[j], 
#                  cosmo_planck18, cf_chi2[j], recenter = False)[1] for j in range(len(L_bol))]
#     ax1.plot(L_bol, b_q, linewidth = 2.5, color = cmap_M_min[k], zorder = 0) # color = cmaps[i][j], alpha = (l+1)/len(bins))
    
M_h = [M(bins_M_min[j], n_m_array[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[0] for j in range(len(L_bol))]
ax1.plot(L_bol, np.log10(M_h), linewidth = 2.5, color = 'lightgreen', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))

M_h = [M(np.logspace(np.log10(M_min_fit[j]), M_max, 79), np.ones(np.shape(bins))*fduty_fit[j], a = a_zbin[j], cosmo = cosmo_planck18, 
         recenter = False)[0] for j in range(len(L_bol))]
ax1.plot(L_bol, np.log10(M_h), linewidth = 2.5, color = 'darkblue', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))

# z = np.linspace(0.8, 2.25)
ax1.fill_between(L_bol, [np.log10(1e12/cosmo_planck18['h'])]*len(L_bol), [np.log10(3e12/cosmo_planck18['h'])]*len(L_bol), alpha = 0.5, 
                 label = 'Chehade et al. 2016', color = 'red')
ax1.set_title('$G<{}$'.format(G_hi))
ax1.fill_between(L_bol, [np.log10(1.6e12/cosmo_planck18['h'])]*len(L_bol), [np.log10(4e12/cosmo_planck18['h'])]*len(L_bol), linewidth = 2.5, 
                 label = 'Eltvedt et al. 2024 (HOD)', alpha = 0.5, color = 'orange')
ax1.fill_between(L_bol, [13.47]*len(L_bol), [13.49]*len(L_bol), alpha = 0.5, label = 'Cordova et al. 2025 (Type I)', color = 'green')

# check redshift range and check cordova type i was right to include because conflicts with this
ax1.fill_between(L_bol, [np.log10(10**12.53/cosmo_planck18['h'])]*len(L_bol), [np.log10(10**12.62/cosmo_planck18['h'])]*len(L_bol), alpha = 0.5, 
                 label = 'Petter et al. 2023 (unobscured)', color = 'blue')

custom_lines = [Line2D([0], [0], color = 'lightgreen', linestyle = ':', linewidth = 2.5), Line2D([0], [0], color = 'darkblue', linestyle = ':', linewidth = 2.5), mpatches.Patch(color='red', alpha = 0.5), 
                mpatches.Patch(color='orange', alpha = 0.5), mpatches.Patch(color='green', alpha = 0.5), mpatches.Patch(color='blue', alpha = 0.5)]
second_legend = ax1.legend(custom_lines, [r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0]), '$\chi^2$ minimization',
                            'Chehade et al. 2016', 'Eltvedt et al. 2024 (HOD)', 'Cordova et al. 2025 (Type I)', 'Petter et al. 2023 (unobscured)'], 
                           ncol = 2, bbox_to_anchor = (0.5, -0.15), loc='upper center')
fig.add_artist(second_legend)

ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
ax1.set_ylabel(r'log$_{10}(\langle M \rangle/M_\odot)$')
ax1.set_xlim(L_bol[0], L_bol[-1])
ax1.set_ylim(12.1, 13.5)

cbar = fig.colorbar(cm.ScalarMappable(cmap=palette_M_min, norm = matplotlib.colors.Normalize(vmin=-1, vmax = 1)), cax = fig.add_subplot(gs[:,-1]), 
                    label = '$\Delta \log_{10}(M_{min}/M_\odot)$')
plt.show()
# Out:
# <>:39: SyntaxWarning: invalid escape sequence '\c'
# <>:44: SyntaxWarning: invalid escape sequence '\l'
# <>:50: SyntaxWarning: invalid escape sequence '\D'
# <>:39: SyntaxWarning: invalid escape sequence '\c'
# <>:44: SyntaxWarning: invalid escape sequence '\l'
# <>:50: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_20608/1145944168.py:39: SyntaxWarning: invalid escape sequence '\c'
#   second_legend = ax1.legend(custom_lines, [r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0]), '$\chi^2$ minimization',
# /tmp/ipykernel_20608/1145944168.py:44: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
# /tmp/ipykernel_20608/1145944168.py:50: SyntaxWarning: invalid escape sequence '\D'
#   label = '$\Delta \log_{10}(M_{min}/M_\odot)$')

# %%
fig = plt.figure(figsize = (10, 8))
labels_cf = ['qq', r'$\xi_{2h}$']
gs = gridspec.GridSpec(1, 3, width_ratios = [1, 0.05, 0.05], wspace = 0)
ax1 = fig.add_subplot(gs[0])
ylim = -7.55, -4.2

for k in range(len(bins)):
    
    n_q_theory = [M(bins_M_min_array[k], n_m_array_2D[j][k], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1] for j in range(len(L_bol))]
    ax1.plot(L_bol, np.log10(n_q_theory), linewidth = 2.5, #alpha = (1+k)/len(bins),
             label = r'$f_{{duty}}: {:.2f}\%-{:.2f}\%, M_{{min}}:[{:.2f}-{:.2f}] M_\odot$'.format(fduty[0]*100, fduty[-1]*100, np.log10(bins[0]), 
                                                                                                  np.log10(bins[-1])), color = cmap[k])

n_q_theory, n_q_theory_fit = [], []
for j in range(len(L_bol)):
    
    n_q_theory.append(M(bins_M_min[j], n_m_array[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1])
    
    n_m=np.ones(np.shape(bins))*fduty_fit[j]
    n_q_theory_fit.append(M(np.logspace(np.log10(M_min_fit[j]), M_max, 79), n_m, a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1])

ax1.plot(L_bol, np.log10(n_q_theory), linewidth = 2.5, color = 'lightgreen', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))
ax1.plot(L_bol, np.log10(n_q_theory_fit), linewidth = 2.5, color = 'darkblue', linestyle = ':', label = r'$\chi^2$ minimization') # color = cmaps[i][j], alpha = (l+1)/len(bins))
ax1.errorbar(L_bol, np.log10(n_q), linewidth = 2.5, marker = 'o', label = 'Quaia', color = 'red',
             yerr = [np.log10(n_q)-np.log10(np.subtract(n_q, n_q_err)), np.log10(np.add(n_q, n_q_err))-np.log10(n_q)], linestyle = 'None')

ax1.set_title('$G<{}$'.format(G_hi))

custom_lines = [Line2D([0], [0], color = 'lightgreen', linestyle = ':', linewidth = 2.5, 
                       label = r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0])),
                Line2D([0], [0], color = 'darkblue', linestyle = ':', linewidth = 2.5, 
                       label = '$\chi^2$ minimization'), 
                Line2D([0], [0], color = 'red', marker = 'o', linestyle = 'None', linewidth = 2.5, label = 'Quaia')]
second_legend = ax1.legend(handles = custom_lines)
fig.add_artist(second_legend)

ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
ax1.set_ylabel(r'log$_{10}(n/(h\mathrm{Mpc}^{-1})^3)$')
ax1.set_ylim(ylim)
ax1.set_xlim(L_bol[0], L_bol[-1])

cbar = fig.colorbar(cm.ScalarMappable(cmap=palette, norm = matplotlib.colors.LogNorm(vmin=bins[0], vmax = bins[-1])), cax = fig.add_subplot(gs[:,-1]), label = '$M_{min}[M_\odot]$')
plt.show()

fig = plt.figure(figsize = (10, 8))
labels_cf = ['qq', r'$\xi_{2h}$']
gs = gridspec.GridSpec(1, 3, width_ratios = [1, 0.05, 0.05], wspace = 0)
ax1 = fig.add_subplot(gs[0])
i = 1
l = 38

for k in range(len(fduty_array)):

    n_q_theory=[]
    for j in range(len(L_bol)):
        
        n_m=np.ones(np.shape(bins))*fduty_array[k]
        n_q_theory.append(M(np.logspace(np.log10(M_min_fit[j]), M_max, 79), n_m, a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1])
        
    ax1.plot(L_bol, np.log10(n_q_theory), linewidth = 2.5, #alpha = (1+k)/len(bins),
             color = cmap_fduty[k])
    
n_q_theory = [M(bins_M_min[j], n_m_array[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1] for j in range(len(L_bol))]
ax1.plot(L_bol, np.log10(n_q_theory), linewidth = 2.5, color = 'lightgreen', linestyle = ':', 
         label = r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0])) # color = cmaps[i][j], alpha = (l+1)/len(bins)) np.log10(bins[l])

ax1.plot(L_bol, np.log10(n_q_theory_fit), linewidth = 2.5, color = 'darkblue', linestyle = ':', label = r'$\chi^2$ minimization') # color = cmaps[i][j], alpha = (l+1)/len(bins))

ax1.errorbar(L_bol, np.log10(n_q), linewidth = 2.5, marker = 'o', label = 'Quaia', color = 'red',
             yerr = [np.log10(n_q)-np.log10(np.subtract(n_q, n_q_err)), np.log10(np.add(n_q, n_q_err))-np.log10(n_q)], linestyle = 'None')

ax1.set_title('$G<{}$'.format(G_hi))

ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
ax1.set_ylabel(r'log$_{10}(n/(h\mathrm{Mpc}^{-1})^3)$')
ax1.set_ylim(ylim)
ax1.legend()
ax1.set_xlim(L_bol[0], L_bol[-1])

cbar = fig.colorbar(cm.ScalarMappable(cmap=palette_fduty, norm = matplotlib.colors.LogNorm(vmin=fduty_array[0], vmax = fduty_array[-1])), cax = fig.add_subplot(gs[:,-1]), label = '$f_{duty}$')
plt.show()
# Out:
# <>:32: SyntaxWarning: invalid escape sequence '\c'
# <>:37: SyntaxWarning: invalid escape sequence '\l'
# <>:42: SyntaxWarning: invalid escape sequence '\o'
# <>:74: SyntaxWarning: invalid escape sequence '\l'
# <>:32: SyntaxWarning: invalid escape sequence '\c'
# <>:37: SyntaxWarning: invalid escape sequence '\l'
# <>:42: SyntaxWarning: invalid escape sequence '\o'
# <>:74: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_20608/153037300.py:32: SyntaxWarning: invalid escape sequence '\c'
#   label = '$\chi^2$ minimization'),
# /tmp/ipykernel_20608/153037300.py:37: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
# /tmp/ipykernel_20608/153037300.py:42: SyntaxWarning: invalid escape sequence '\o'
#   cbar = fig.colorbar(cm.ScalarMappable(cmap=palette, norm = matplotlib.colors.LogNorm(vmin=bins[0], vmax = bins[-1])), cax = fig.add_subplot(gs[:,-1]), label = '$M_{min}[M_\odot]$')
# /tmp/ipykernel_20608/153037300.py:74: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
# /tmp/ipykernel_20608/2313523635.py:30: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1/n_g*np.trapz(integrand*b, bins)
# /tmp/ipykernel_20608/2313523635.py:30: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1/n_g*np.trapz(integrand*b, bins)
# /tmp/ipykernel_20608/153037300.py:10: RuntimeWarning: divide by zero encountered in log10
#   ax1.plot(L_bol, np.log10(n_q_theory), linewidth = 2.5, #alpha = (1+k)/len(bins),

# %%
cmap_fduty_k = sns.color_palette("vlag", n_colors = len(fduty_array))

# %%
fig = plt.figure(figsize = (10, 8))
labels_cf = ['qq', r'$\xi_{2h}$']
gs = gridspec.GridSpec(1, 3, width_ratios = [1, 0.05, 0.05], wspace = 0)
ax1 = fig.add_subplot(gs[0])
# ylim = -6.5, -4.75

for k in range(len(bins)):
    
    n_q_theory = [M(np.logspace(np.log10(M_min_fit[j])-1+k/int(len(bins)/2), M_max, 79), np.ones(np.shape(bins))*fduty_fit[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1] for j in range(len(L_bol))]
    ax1.plot(L_bol, np.log10(n_q_theory), linewidth = 2.5, #alpha = (1+k)/len(bins),
             label = r'$f_{{duty}}: {:.2f}\%-{:.2f}\%, M_{{min}}:[{:.2f}-{:.2f}] M_\odot$'.format(fduty[0]*100, fduty[-1]*100, np.log10(bins[0]), 
                                                                                                  np.log10(bins[-1])), color = cmap_M_min[k])

# for k in range(len(bins)):
    
#     M_h = [M(np.logspace(np.log10(M_min_fit[j])-1+k/int(len(bins)/2), M_max, 79), np.ones(np.shape(bins))*fduty_fit[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[0] for j in range(len(L_bol))]
#     ax1.plot(L_bol, np.log10(M_h), linewidth = 2.5, 
#              label = r'$f_{{duty}}: {:.2f}\%-{:.2f}\%, M_{{min}}:{:.2f} M_\odot$'.format(fduty[0]*100, fduty[-1]*100, np.log10(bins[k])),
#              color = cmap_M_min[k], zorder = 0) #, alpha = (1+k)/len(bins))
    
n_q_theory, n_q_theory_fit = [], []
for j in range(len(L_bol)):
    
    n_q_theory.append(M(bins_M_min[j], n_m_array[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1])
    
    n_m=np.ones(np.shape(bins))*fduty_fit[j]
    n_q_theory_fit.append(M(np.logspace(np.log10(M_min_fit[j]), M_max, 79), n_m, a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1])

ax1.plot(L_bol, np.log10(n_q_theory), linewidth = 2.5, color = 'lightgreen', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))
ax1.plot(L_bol, np.log10(n_q_theory_fit), linewidth = 2.5, color = 'darkblue', linestyle = ':', label = r'$\chi^2$ minimization') # color = cmaps[i][j], alpha = (l+1)/len(bins))
ax1.errorbar(L_bol, np.log10(n_q), linewidth = 2.5, marker = 'o', label = 'Quaia', color = 'red',
             yerr = [np.log10(n_q)-np.log10(np.subtract(n_q, n_q_err)), np.log10(np.add(n_q, n_q_err))-np.log10(n_q)], linestyle = 'None')

ax1.set_title('$G<{}$'.format(G_hi))
ax1.set_xlim(L_bol[0], L_bol[-1])

custom_lines = [Line2D([0], [0], color = 'lightgreen', linestyle = ':', linewidth = 2.5, 
                       label = r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0])),
                Line2D([0], [0], color = 'darkblue', linestyle = ':', linewidth = 2.5, 
                       label = '$\chi^2$ minimization'), 
                Line2D([0], [0], color = 'red', marker = 'o', linestyle = 'None', linewidth = 2.5, label = 'Quaia')]
second_legend = ax1.legend(handles = custom_lines)
fig.add_artist(second_legend)

ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
ax1.set_ylabel(r'log$_{10}(n/(h\mathrm{Mpc}^{-1})^3)$')
ax1.set_ylim(ylim)

cbar = fig.colorbar(cm.ScalarMappable(cmap=palette_M_min, norm = matplotlib.colors.Normalize(vmin=-1, vmax = 1)), cax = fig.add_subplot(gs[:,-1]), 
                    label = '$\Delta \log_{10}(M_{min}/M_\odot)$')
plt.show()

fig = plt.figure(figsize = (10, 8))
labels_cf = ['qq', r'$\xi_{2h}$']
gs = gridspec.GridSpec(1, 3, width_ratios = [1, 0.05, 0.05], wspace = 0)
ax1 = fig.add_subplot(gs[0])
i = 1
l = 38

for k in range(len(fduty_array)):

    n_q_theory=[]
    for j in range(len(L_bol)):
        
        # n_m=np.ones(np.shape(bins))*fduty_array[k]
        n_m = np.ones(np.shape(bins))*10**(np.log10(fduty_fit[j])-1+k/int(len(fduty_array)/2))
        n_q_theory.append(M(np.logspace(np.log10(M_min_fit[j]), M_max, 79), n_m, a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1])
        
    ax1.plot(L_bol, np.log10(n_q_theory), linewidth = 2.5, #alpha = (1+k)/len(bins),
             color = cmap_fduty_k[k])
    
n_q_theory = [M(bins_M_min[j], n_m_array[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1] for j in range(len(L_bol))]
ax1.plot(L_bol, np.log10(n_q_theory), linewidth = 2.5, color = 'lightgreen', linestyle = ':', 
         label = r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0])) # color = cmaps[i][j], alpha = (l+1)/len(bins)) np.log10(bins[l])

ax1.plot(L_bol, np.log10(n_q_theory_fit), linewidth = 2.5, color = 'darkblue', linestyle = ':', label = r'$\chi^2$ minimization') # color = cmaps[i][j], alpha = (l+1)/len(bins))

ax1.errorbar(L_bol, np.log10(n_q), linewidth = 2.5, marker = 'o', label = 'Quaia', color = 'red',
             yerr = [np.log10(n_q)-np.log10(np.subtract(n_q, n_q_err)), np.log10(np.add(n_q, n_q_err))-np.log10(n_q)], linestyle = 'None')

ax1.set_title('$G<{}$'.format(G_hi))

ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
ax1.set_ylabel(r'log$_{10}(n/(h\mathrm{Mpc}^{-1})^3)$')
ax1.set_ylim(ylim)
ax1.legend()
ax1.set_xlim(L_bol[0], L_bol[-1])

cbar = fig.colorbar(cm.ScalarMappable(cmap=palette_M_min, norm = matplotlib.colors.Normalize(vmin=-1, vmax = 1)), cax = fig.add_subplot(gs[:,-1]), 
                    label = '$\Delta \log_{10}(f_{duty})$')
plt.show()
# Out:
# <>:40: SyntaxWarning: invalid escape sequence '\c'
# <>:45: SyntaxWarning: invalid escape sequence '\l'
# <>:50: SyntaxWarning: invalid escape sequence '\D'
# <>:83: SyntaxWarning: invalid escape sequence '\l'
# <>:90: SyntaxWarning: invalid escape sequence '\D'
# <>:40: SyntaxWarning: invalid escape sequence '\c'
# <>:45: SyntaxWarning: invalid escape sequence '\l'
# <>:50: SyntaxWarning: invalid escape sequence '\D'
# <>:83: SyntaxWarning: invalid escape sequence '\l'
# <>:90: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_20608/95340801.py:40: SyntaxWarning: invalid escape sequence '\c'
#   label = '$\chi^2$ minimization'),
# /tmp/ipykernel_20608/95340801.py:45: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
# /tmp/ipykernel_20608/95340801.py:50: SyntaxWarning: invalid escape sequence '\D'
#   label = '$\Delta \log_{10}(M_{min}/M_\odot)$')
# /tmp/ipykernel_20608/95340801.py:83: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
# /tmp/ipykernel_20608/95340801.py:90: SyntaxWarning: invalid escape sequence '\D'
#   label = '$\Delta \log_{10}(f_{duty})$')

# %% [markdown]
# # Plot the QLF

# %%
def phi(z, M):

    
    F_0 = np.polynomial.chebyshev.Chebyshev((-7.798, 1.128, -0.120))
    phi_star = 10**F_0(1+z)

    F_1 = np.polynomial.chebyshev.Chebyshev((-17.163, -5.512, 0.593, -0.024))
    M_star = F_1(1+z)

    F_2 = np.polynomial.chebyshev.Chebyshev((-3.223, -0.258))
    alpha = F_2(1+z)

    zeta = np.log10((1+z)/(1+3.773))
    beta = -2.312+0.559/(10**(141.884*zeta)+10**(-0.171*zeta))

    return phi_star/(10**(0.4*(alpha+1)*(M-M_star))+10**(0.4*(beta+1)*(M-M_star)))/u.Mpc**3/u.mag

# %% [markdown]
#  ## Convert bolometric luminosity to monochromatic luminosity at a rest frame of $1450\mathring{A}$

# %%
def L_lambda(L_bol, angstrom = 1450*u.angstrom):
    
    A = 4.74
    B = 0.91
    # angstrom = 1450*u.angstrom # Angstrom
    
    try:
        L_bol = L_bol.value
    except:
        pass
        
    return (L_bol/10**A)**(1/B)*u.erg/u.s/angstrom

# %% [markdown]
# ## Convert monochromatic luminosity to absolute AB magnitude

# %%
def m_AB(L_bol, angstrom = 1450*u.angstrom):

    d = 10*u.pc
    # f_v = angstrom**2/const.c*L_lambda(tab_datahi_mask_zbin0['L_bol'], angstrom)/(4*np.pi*d**2)
    f_lambda = L_lambda(L_bol, angstrom = angstrom)/(4*np.pi*d**2)
    # f_v = f_lambda.to(u.erg/u.s/u.cm**2/u.Hz, u.spectral_density(angstrom))
    
    # return -2.5*np.log10(f_v/(3631*u.Jy))
    return f_lambda.to(u.ABmag, u.spectral_density(angstrom))

# %%
m_AB(tab_datahi_mask_zbin0['L_bol'])
# Out:
# <Magnitude [-27.03430165, -25.25641942, -25.42117004, ..., -24.9272143 ,
#             -25.39313916, -26.87510024] mag(AB)>

# %% [markdown]
# ## Integrate the QLF

# %%
z_array = np.linspace(0,1)

# %%
N_exp = []
for i in range(len(L_bol)):
    
    M_array = m_AB(np.logspace(L_bol[i], 49)).value[::-1]
    dz, dM = np.meshgrid(z_array, M_array)
    
    cp = np.percentile(selfunc_hi_bins[i], mask*100)
    f_sky = 1/(4*np.pi)*np.sum(selfunc_hi_bins[i][selfunc_hi_bins[i]>=cp]*hp.nside2pixarea(NSIDE))
    dV_dz = f_sky*Planck18.differential_comoving_volume(dz)*4*np.pi*u.sr #*cosmo_quaia['h']**3 # convert to 1/Mpc^3
    
    # phi_dM = np.trapz(phi(dz, dM)*V_eff[i].to(u.Mpc**3, cu.with_H0(H0)), z_array)
    phi_dM = np.trapz(phi(dz, dM)*dV_dz, z_array)
    N_exp.append(np.trapz(phi_dM, M_array)*u.mag)

# %%
zmax = quaia.comoving_dist(1, h = cosmo_planck18['h'], Om0 = cosmo_planck18['Omega_m']) #) cosmos[i]['Omega_m']+cosmos[i]['Omega_c']).value # Mpc/h
zmin = quaia.comoving_dist(0, h = cosmo_planck18['h'], Om0 = cosmo_planck18['Omega_m']) #cosmos[i]['Omega_b']+cosmos[i]['Omega_c']).value # Mpc/h
4/3*np.pi*(zmax**3-zmin**3)
# Out:
# <Quantity 5.04318477e+10 Mpc3 / littleh3>

# %%
Planck18.comoving_volume(1)*cosmo_planck18['h']**3/u.h**3
# Out:
# <Quantity 5.07980909e+10 Mpc3 / h3>

# %%
np.trapz(Planck18.differential_comoving_volume(z_array)*np.pi*4*u.sr*cosmo_planck18['h']**3/u.h**3, z_array)
# Out:
# <Quantity 5.08014823e+10 Mpc3 / h3>

# %%
fig = plt.figure(figsize = (10, 10))
gs = gridspec.GridSpec(2, 1, height_ratios = [1, 0.25], hspace = 0)
ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])

ax1.scatter(L_bol, N_q, label = 'Quaia')
ax1.plot(L_bol, N_exp, linestyle = '--', label = '$L_\mathrm{bol}\geq L_\mathrm{bol,min}$')
ax1.set_ylabel('$N_{\mathrm{QSO},0<z\leq1}$')
ax1.set_yscale('log')
ax1.legend()

ax2.plot(L_bol,np.array(N_q)/N_exp, marker = 'o', linestyle = '--')
ax2.axhline(1, linestyle = ':')
ax2.set_xlabel('$\log_{10}(L_\mathrm{bol,min}/(\mathrm{erg }s^{-1}))$')
ax2.set_ylabel('$N_\mathrm{Quaia}/N_\mathrm{exp}$')
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:14: SyntaxWarning: invalid escape sequence '\l'
# <>:15: SyntaxWarning: invalid escape sequence '\m'
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:14: SyntaxWarning: invalid escape sequence '\l'
# <>:15: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_20608/1261825789.py:7: SyntaxWarning: invalid escape sequence '\m'
#   ax1.plot(L_bol, N_exp, linestyle = '--', label = '$L_\mathrm{bol}\geq L_\mathrm{bol,min}$')
# /tmp/ipykernel_20608/1261825789.py:8: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_ylabel('$N_{\mathrm{QSO},0<z\leq1}$')
# /tmp/ipykernel_20608/1261825789.py:14: SyntaxWarning: invalid escape sequence '\l'
#   ax2.set_xlabel('$\log_{10}(L_\mathrm{bol,min}/(\mathrm{erg }s^{-1}))$')
# /tmp/ipykernel_20608/1261825789.py:15: SyntaxWarning: invalid escape sequence '\m'
#   ax2.set_ylabel('$N_\mathrm{Quaia}/N_\mathrm{exp}$')

# %%
fig = plt.figure(figsize = (10, 10))
gs = gridspec.GridSpec(2, 1, height_ratios = [1, 0.25], hspace = 0)
ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])

for i in range(len(L_bol)):
    ax1.scatter(zbin[i], N_q[i], label = 'Quaia', color = cmap_blue[i])
    ax1.scatter(zbin[i], N_exp[i], linestyle = '--', label = '$L_\mathrm{{bol}}\geq 10^{{{}}} \mathrm{{erg }}s^{{-1}}$'.format(L_bol[i]), color = cmap_blue[i], marker = 'P')
    ax2.plot(zbin[i],np.array(N_q)[i]/N_exp[i], color = cmap_blue[i], marker = 'o', linestyle = '--')

ax1.set_ylabel('$N_{\mathrm{QSO},0<z\leq1}$')
ax1.set_yscale('log')
ax1.set_xlim(0,1.5)
ax1.set_xticklabels([])
# ax1.legend()

ax2.axhline(1, linestyle = ':')
ax2.set_xlabel('$z$')
ax2.set_ylabel('$N_\mathrm{Quaia}/N_\mathrm{exp}$')
ax2.set_xlim(0,1.5)

custom_lines = [Line2D([0], [0], color = 'black', linestyle = 'none', marker = 'o'), Line2D([0], [0], color = 'black', linestyle = 'none', marker = 'P')]
second_legend = ax1.legend(custom_lines, [r'$N_\mathrm{Quaia}$', '$N_\mathrm{exp}$'])
fig.add_artist(second_legend)

custom_lines = [mpatches.Patch(color=color) for color in cmap_blue]
first_legend = ax1.legend(custom_lines, ['$L_\mathrm{{bol}}\geq 10^{{{}}} \mathrm{{erg }}s^{{-1}}$'.format(L) for L in L_bol], loc = 'lower left')
fig.add_artist(first_legend)

plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:11: SyntaxWarning: invalid escape sequence '\m'
# <>:19: SyntaxWarning: invalid escape sequence '\m'
# <>:23: SyntaxWarning: invalid escape sequence '\m'
# <>:27: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:11: SyntaxWarning: invalid escape sequence '\m'
# <>:19: SyntaxWarning: invalid escape sequence '\m'
# <>:23: SyntaxWarning: invalid escape sequence '\m'
# <>:27: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_20608/3755423760.py:8: SyntaxWarning: invalid escape sequence '\m'
#   ax1.scatter(zbin[i], N_exp[i], linestyle = '--', label = '$L_\mathrm{{bol}}\geq 10^{{{}}} \mathrm{{erg }}s^{{-1}}$'.format(L_bol[i]), color = cmap_blue[i], marker = 'P')
# /tmp/ipykernel_20608/3755423760.py:11: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_ylabel('$N_{\mathrm{QSO},0<z\leq1}$')
# /tmp/ipykernel_20608/3755423760.py:19: SyntaxWarning: invalid escape sequence '\m'
#   ax2.set_ylabel('$N_\mathrm{Quaia}/N_\mathrm{exp}$')
# /tmp/ipykernel_20608/3755423760.py:23: SyntaxWarning: invalid escape sequence '\m'
#   second_legend = ax1.legend(custom_lines, [r'$N_\mathrm{Quaia}$', '$N_\mathrm{exp}$'])
# /tmp/ipykernel_20608/3755423760.py:27: SyntaxWarning: invalid escape sequence '\m'
#   first_legend = ax1.legend(custom_lines, ['$L_\mathrm{{bol}}\geq 10^{{{}}} \mathrm{{erg }}s^{{-1}}$'.format(L) for L in L_bol], loc = 'lower left')

# %% [markdown]
# ## Redo with updated $N_\mathrm{exp}$ constraint

# %%
error = [0.05, 0.05, 0.05, 0.05, 0.05]
res, M_min_fit, fduty_fit = [], [], []

chi2_grid = {j: np.zeros((len(bins), len(fduty_array))) for j in range(len(L_bol))}
cons_grid = {j: np.zeros((len(bins), len(fduty_array))) for j in range(len(L_bol))}


for j in range(len(L_bol)):
    
    C = np.load('../results/cov_xi_G{}_rmin{}_rmax{}_nbins{}_z0.0_Lbolmin{:.1f}_N25_Planck.npy'.format(G_hi, rmin, rmax, nbins, L_bol[j]))
    
    ix_grid = np.ix_(rpmask, rpmask)
    if j > 2:
        correction = 1
    else:
        # correction = np.min((N_q[i]/N_exp[i], 1))
        correction = (N_q[j]/N_exp[j]).value
    fun = lambda x: f0_GLS_solve(x, a_zbin[j], cf_matter_chi2[j][rpmask], C[ix_grid], cf_chi2[j][rpmask], n_q[j]/correction)
    cons = ({'type': 'ineq', 'fun': lambda x: constraint(x, a_zbin[j], n_q[j]/correction, error = error[j])}) 
    
    result = minimize(fun, [fduty[0], M_min_array[0]], bounds = ((0,1), (9, 15)), constraints = cons, method = 'trust-constr')
    
    print('L>={} erg/s'.format(L_bol[j]))
    x = result.x[0], result.x[-1]
    
    ix_grid = np.ix_(rpmask, rpmask)f
    chi2 = f0_GLS_solve(x, a_zbin[j], cf_matter_chi2[j][rpmask], C[ix_grid], cf_chi2[j][rpmask], n_q[j]/correction)
    df = nbins-len(x)
    
    print('           chi^2: {:.2f}'.format(chi2))
    print('   reduced chi^2: {:.2f}'.format(chi2/df))
    print('         delta n: {:.2e}'.format(constraint(x, a_zbin[j], n_q[j], error = error[j])))
    print('condition number: {:.2f}'.format(np.linalg.cond(C)))
    print('             PTE: {:.2e}\n'.format(stats.chi2.sf(chi2, df)))
    
    for k in range(len(fduty_array)):
        
        for l in range(len(bins)):
            
            x = fduty_array[k], np.log10(bins[l])

            chi2_m = f0_GLS_solve(x, a_zbin[j], cf_matter_chi2[j][rpmask], C[ix_grid], cf_chi2[j][rpmask], n_q[j]/correction)
            chi2_grid[j][l,k]=chi2_m
            cons = constraint(x, a_zbin[j], n_q[j]/correction, error = error[j])
            cons_grid[j][l,k]=cons
            
    M_min_fit.append(10**result.x[-1])
    fduty_fit.append(result.x[0])
    res.append(result)
    
np.log10(M_min_fit), np.log10(fduty_fit), res
# Out:
# L>=44.5 erg/s
#            chi^2: 118.20
#    reduced chi^2: 1.71
#          delta n: -2.87e+00
# condition number: 134792852686848311296.00
#              PTE: 2.11e-04
# /tmp/ipykernel_20608/2313523635.py:30: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1/n_g*np.trapz(integrand*b, bins)
# /tmp/ipykernel_20608/2313523635.py:30: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1/n_g*np.trapz(integrand*b, bins)
# /home/groups/tabel/mahlet/pyccl-env/lib/python3.12/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# L>=45.0 erg/s
#            chi^2: 139.24
#    reduced chi^2: 2.02
#          delta n: -2.74e-01
# condition number: 37630326030582431744.00
#              PTE: 1.17e-06
#
# L>=45.5 erg/s
#            chi^2: 79.84
#    reduced chi^2: 1.16
#          delta n: -2.69e-01
# condition number: 251004634542490681344.00
#              PTE: 1.75e-01
#
# L>=46.0 erg/s
#            chi^2: 21.52
#    reduced chi^2: 0.31
#          delta n: 5.00e-02
# condition number: 123364612420862066688.00
#              PTE: 1.00e+00
#
# L>=46.5 erg/s
#            chi^2: 317.59
#    reduced chi^2: 4.60
#          delta n: 4.78e-02
# condition number: 16164615762696488960.00
#              PTE: 1.46e-33
# (array([12.24199468, 12.421317  , 12.06534632, 12.23360023, 10.86480592]),
#  array([-1.82561487, -2.12733791, -3.03201581, -3.56860644, -6.41511404]),
#  [           message: `xtol` termination condition is satisfied.
#              success: True
#               status: 2
#                  fun: 118.1952804136201
#                    x: [ 1.494e-02  1.224e+01]
#                  nit: 153
#                 nfev: 492
#                 njev: 164
#                 nhev: 0
#             cg_niter: 165
#         cg_stop_cond: 2
#                 grad: [-9.537e-07  2.254e-01]
#      lagrangian_grad: [-1.318e-03  4.630e-02]
#               constr: [array([ 5.000e-02]), array([ 1.494e-02,  1.224e+01])]
#                  jac: [array([[-6.693e+01, -1.910e+00]]), array([[ 1.000e+00,  0.000e+00],
#                              [ 0.000e+00,  1.000e+00]])]
#          constr_nfev: [492, 0]
#          constr_njev: [0, 0]
#          constr_nhev: [0, 0]
#                    v: [array([ 8.825e-02]), array([ 5.905e+00, -1.049e-02])]
#               method: tr_interior_point
#           optimality: 0.04629981183136112
#     constr_violation: 0.0
#       execution_time: 0.4184107780456543
#            tr_radius: 7.0015143070332e-09
#       constr_penalty: 1.0
#    barrier_parameter: 2.048000000000001e-09
#    barrier_tolerance: 2.048000000000001e-09
#                niter: 153,
#              message: `xtol` termination condition is satisfied.
#              success: True
#               status: 2
#                  fun: 139.23959328908614
#                    x: [ 7.459e-03  1.242e+01]
#                  nit: 78
#                 nfev: 270
#                 njev: 90
#                 nhev: 0
#             cg_niter: 82
#         cg_stop_cond: 4
#                 grad: [ 3.815e-06  3.071e-06]
#      lagrangian_grad: [ 7.922e-09  4.353e-07]
#               constr: [array([ 4.965e-02]), array([ 7.459e-03,  1.242e+01])]
#                  jac: [array([[-1.341e+02,  2.447e+00]]), array([[ 1.000e+00,  0.000e+00],
#                              [ 0.000e+00,  1.000e+00]])]
#          constr_nfev: [270, 0]
#          constr_njev: [0, 0]
#          constr_nhev: [0, 0]
#                    v: [array([-1.035e-06]), array([-1.427e-04, -1.024e-07])]
#               method: tr_interior_point
#           optimality: 4.3527240808346446e-07
#     constr_violation: 0.0
#       execution_time: 0.2325146198272705
#            tr_radius: 1.0000000000000005e-09
#       constr_penalty: 1.0
#    barrier_parameter: 2.048000000000001e-09
#    barrier_tolerance: 2.048000000000001e-09
#                niter: 78,
#              message: `xtol` termination condition is satisfied.
#              success: True
#               status: 2
#                  fun: 79.8371855986101
#                    x: [ 9.289e-04  1.207e+01]
#                  nit: 296
#                 nfev: 888
#                 njev: 296
#                 nhev: 0
#             cg_niter: 299
#         cg_stop_cond: 2
#                 grad: [-9.537e-07  4.479e-03]
#      lagrangian_grad: [-8.651e-06  3.505e-03]
#               constr: [array([ 5.000e-02]), array([ 9.289e-04,  1.207e+01])]
#                  jac: [array([[-9.532e+02, -2.353e+00]]), array([[ 1.000e+00,  0.000e+00],
#                              [ 0.000e+00,  1.000e+00]])]
#          constr_nfev: [888, 0]
#          constr_njev: [0, 0]
#          constr_nhev: [0, 0]
#                    v: [array([ 8.559e-05]), array([ 8.158e-02, -7.724e-04])]
#               method: tr_interior_point
#           optimality: 0.0035047821591426657
#     constr_violation: 0.0
#       execution_time: 0.7873449325561523
#            tr_radius: 5.544034737963461e-09
#       constr_penalty: 1.0
#    barrier_parameter: 2.048000000000001e-09
#    barrier_tolerance: 2.048000000000001e-09
#                niter: 296,
#              message: `xtol` termination condition is satisfied.
#              success: True
#               status: 2
#                  fun: 21.517883228243523
#                    x: [ 2.700e-04  1.223e+01]
#                  nit: 324
#                 nfev: 972
#                 njev: 324
#                 nhev: 0
#             cg_niter: 320
#         cg_stop_cond: 2
#                 grad: [ 0.000e+00 -1.350e+00]
#      lagrangian_grad: [-7.319e-04 -1.113e+00]
#               constr: [array([ 4.999e-02]), array([ 2.700e-04,  1.223e+01])]
#                  jac: [array([[-3.703e+03,  2.435e+00]]), array([[ 1.000e+00,  0.000e+00],
#                              [ 0.000e+00,  1.000e+00]])]
#          constr_nfev: [972, 0]
#          constr_njev: [0, 0]
#          constr_nhev: [0, 0]
#                    v: [array([ 4.661e-05]), array([ 1.719e-01,  2.369e-01])]
#               method: tr_interior_point
#           optimality: 1.1132138468686728
#     constr_violation: 0.0
#       execution_time: 0.8584668636322021
#            tr_radius: 5.407404314902385e-09
#       constr_penalty: 1.0
#    barrier_parameter: 2.048000000000001e-09
#    barrier_tolerance: 2.048000000000001e-09
#                niter: 324,
#              message: `xtol` termination condition is satisfied.
#              success: True
#               status: 2
#                  fun: 317.5880028391374
#                    x: [ 3.845e-07  1.086e+01]
#                  nit: 367
#                 nfev: 1101
#                 njev: 367
#                 nhev: 0
#             cg_niter: 355
#         cg_stop_cond: 2
#                 grad: [ 0.000e+00  6.037e-01]
#      lagrangian_grad: [ 3.744e-07  4.579e-01]
#               constr: [array([ 4.777e-02]), array([ 3.845e-07,  1.086e+01])]
#                  jac: [array([[-2.607e+06,  2.131e+00]]), array([[ 1.000e+00,  0.000e+00],
#                              [ 0.000e+00,  1.000e+00]])]
#          constr_nfev: [1101, 0]
#          constr_njev: [0, 0]
#          constr_nhev: [0, 0]
#                    v: [array([-6.450e-11]), array([-1.678e-04, -1.458e-01])]
#               method: tr_interior_point
#           optimality: 0.45794824057508765
#     constr_violation: 0.0
#       execution_time: 0.9693610668182373
#            tr_radius: 5.119261409427282e-09
#       constr_penalty: 1.0
#    barrier_parameter: 2.048000000000001e-09
#    barrier_tolerance: 2.048000000000001e-09
#                niter: 367])

# %%
fig = plt.figure(figsize = (20, 40))
gs = gridspec.GridSpec(5, 2, hspace = 0.15, wspace = 0.1)

for j in range(len(L_bol)):
    
    ax1 = fig.add_subplot(gs[j*2])
    image = ax1.imshow(np.log10(chi2_grid[j]), cmap = cmap_chi2, vmin = np.log10(50.13706414974333), vmax = np.log10(3216118165719.2197), extent =  [np.log10(fduty_array[0]), np.log10(fduty_array[-1]), np.log10(bins[0]), np.log10(bins[-1])], aspect = 'auto', origin = 'lower')
    ax1.set_title('$L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(L_bol[j]))
    if j == 4:
        ax1.set_xlabel('$\log_{10} (f_{duty})$')
    ax1.set_ylabel('$\log_{10} (M_{min}/M_\odot)$')
    fig.colorbar(image, label='$\log_{10} (\chi^2)$')
    ax1.axhline(np.log10(M_min_fit[j]), color = 'red', linestyle = '--')
    ax1.axvline(np.log10(fduty_fit[j]), color = 'red', linestyle = '--')
    
    ax1 = fig.add_subplot(gs[j*2+1])
    image = ax1.imshow(cons_grid[j], cmap = palette_fduty, norm = 'symlog', vmin = -4348491.828200184, vmax = 0.09959201649593023, extent = [np.log10(fduty_array[0]), np.log10(fduty_array[-1]), np.log10(bins[0]), np.log10(bins[-1])], aspect = 'auto', origin = 'lower')
    ax1.set_title('$L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(L_bol[j]))
    if j == 4:
        ax1.set_xlabel('$\log_{10} (f_{duty})$')
    fig.colorbar(image, label='$\Delta n_q$')
    ax1.axhline(np.log10(M_min_fit[j]), color = 'red', linestyle = '--')
    ax1.axvline(np.log10(fduty_fit[j]), color = 'red', linestyle = '--')

plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\l'
# <>:11: SyntaxWarning: invalid escape sequence '\l'
# <>:12: SyntaxWarning: invalid escape sequence '\l'
# <>:18: SyntaxWarning: invalid escape sequence '\m'
# <>:20: SyntaxWarning: invalid escape sequence '\l'
# <>:21: SyntaxWarning: invalid escape sequence '\D'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\l'
# <>:11: SyntaxWarning: invalid escape sequence '\l'
# <>:12: SyntaxWarning: invalid escape sequence '\l'
# <>:18: SyntaxWarning: invalid escape sequence '\m'
# <>:20: SyntaxWarning: invalid escape sequence '\l'
# <>:21: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_20608/676983591.py:8: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_title('$L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(L_bol[j]))
# /tmp/ipykernel_20608/676983591.py:10: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10} (f_{duty})$')
# /tmp/ipykernel_20608/676983591.py:11: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_ylabel('$\log_{10} (M_{min}/M_\odot)$')
# /tmp/ipykernel_20608/676983591.py:12: SyntaxWarning: invalid escape sequence '\l'
#   fig.colorbar(image, label='$\log_{10} (\chi^2)$')
# /tmp/ipykernel_20608/676983591.py:18: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_title('$L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(L_bol[j]))
# /tmp/ipykernel_20608/676983591.py:20: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10} (f_{duty})$')
# /tmp/ipykernel_20608/676983591.py:21: SyntaxWarning: invalid escape sequence '\D'
#   fig.colorbar(image, label='$\Delta n_q$')

# %% [markdown]
# ### Plot results

# %%
plt.plot(L_bol, np.log10(M_min_fit), color = 'darkblue', linewidth = 2.5, label = 'Shiferaw et al. 2026 (this work)')
plt.axhline(M_min_array[0], label = 'Giner Mascarell et al. 2025', color = 'lightgreen', linewidth = 2.5, linestyle = '--')
plt.ylabel('$\log_{10}(M_{min}/M_\odot)$')
plt.xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
plt.legend(bbox_to_anchor = (0.5, -0.2), loc='upper center')
plt.xlim(L_bol[0], L_bol[-1])
plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\l'
# <>:4: SyntaxWarning: invalid escape sequence '\l'
# <>:3: SyntaxWarning: invalid escape sequence '\l'
# <>:4: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_20608/3432766316.py:3: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel('$\log_{10}(M_{min}/M_\odot)$')
# /tmp/ipykernel_20608/3432766316.py:4: SyntaxWarning: invalid escape sequence '\l'
#   plt.xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')

# %%
plt.plot(L_bol, np.log10(fduty_fit), color = 'darkblue', linewidth = 2.5, label = 'Shiferaw et al. 2026 (this work)')
plt.fill_between(L_bol, [np.log10(fduty[0]+fduty_err_hi[0])]*len(L_bol), [np.log10(fduty[0]-fduty_err_lo[0])]*len(L_bol), alpha = 0.5, 
                 color = 'lightgreen')
plt.axhline(np.log10(fduty[0]), label = 'Giner Mascarell et al. 2025', color = 'lightgreen', linewidth = 2.5, linestyle = '--')
plt.ylabel('$\log_{10}(f_{duty})$')
plt.xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
plt.legend(bbox_to_anchor = (0.5, -0.2), loc='upper center')
plt.xlim(L_bol[0], L_bol[-1])
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\l'
# <>:6: SyntaxWarning: invalid escape sequence '\l'
# <>:5: SyntaxWarning: invalid escape sequence '\l'
# <>:6: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_20608/1055270469.py:5: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel('$\log_{10}(f_{duty})$')
# /tmp/ipykernel_20608/1055270469.py:6: SyntaxWarning: invalid escape sequence '\l'
#   plt.xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')

# %%
# plot!
fig = plt.figure(figsize = (24,16))  #13.5
grid = gridspec.GridSpec(5, 6, height_ratios = [1, 0.5, 0.35, 1, 0.5], hspace = 0) #0.25

ax1 = plt.subplot(grid[0, 0:2])
ax2 = plt.subplot(grid[0, 2:4])
ax3 = plt.subplot(grid[0, 4:6])
ax4 = plt.subplot(grid[3, 1:3])
ax5 = plt.subplot(grid[3, 3:5])
axlist = [ax1, ax2, ax3, ax4, ax5] #https://www.geeksforgeeks.org/matplotlib-gridspec-gridspec-class-in-python/

ax6 = plt.subplot(grid[1, 0:2])
ax7 = plt.subplot(grid[1, 2:4])
ax8 = plt.subplot(grid[1, 4:6])
ax9 = plt.subplot(grid[4, 1:3])
ax10 = plt.subplot(grid[4, 3:5])
axlist2 = [ax6, ax7, ax8, ax9, ax10] #https://www.geeksforgeeks.org/matplotlib-gridspec-gridspec-class-in-python/

ylim = 2e-6, 4
k = 0
for j in range(len(L_bol)):

    ax1 = axlist[j]
    ax2 = axlist2[j]
    
    C = np.load('../results/cov_xi_G{}_rmin{}_rmax{}_nbins{}_z0.0_Lbolmin{:.1f}_N25_Planck.npy'.format(G_hi, rmin, rmax, nbins, L_bol[j]))
            
    ax1.errorbar(quaia.recenter(rbins_chi2), cf_chi2[j], linewidth = 2.5, marker = 'o', 
                 color = 'red',
                yerr = np.sqrt(np.diag(C)), markeredgewidth = 2.5, capsize = 2.5, linestyle = 'none')
    ax1.plot(quaia.recenter(rbins_chi2), b_eff_cf20[0]**2*cf_matter_chi2[j], linewidth = 2.5,
             color = 'orange', linestyle = '--')
    ax1.fill_betweenx(np.linspace(ylim[0], ylim[1]), x1 = quaia.recenter(rbins_chi2)[0], x2 = 30, color = 'grey', 
                      alpha = 0.5) # label = 'scales excluded from fit')
    ax1.fill_betweenx(np.linspace(ylim[0], ylim[1]), x1 = 80, x2 = quaia.recenter(rbins_chi2)[-1], color = 'grey', 
                      alpha = 0.5)

    # old fit
    cf_2h_zbin, b_q = cf_2h(bins_M_min[j], n_m_array[j], a_zbin[j], cosmo_planck18, cf_matter_chi2[j], recenter = False)
    ax1.plot(quaia.recenter(rbins_chi2), cf_2h_zbin, linewidth = 2.5, 
             color = 'lightgreen')
    ax2.axhline(b_q, linewidth = 2.5, color = 'lightgreen')

    # plot new fit
    n_m=np.ones(np.shape(bins))*fduty_fit[j]
    cf_2h_zbin, b_q = cf_2h(np.logspace(np.log10(M_min_fit[j]),M_max,79), n_m, a_zbin[j], cosmo_planck18, cf_matter_chi2[j], 
                            recenter = False)
    ax1.plot(quaia.recenter(rbins_chi2), cf_2h_zbin, linewidth = 2.5,
             label = r'$\xi_{{q,2h}}(f_{{duty}}=10^{{{:.2f}}}, M_{{min}}=10^{{{:.2f}}}M_\odot)$'.format(np.log10(fduty_fit[j]), 
                                                                                                        np.log10(M_min_fit[j])), 
             color = 'darkblue')
    ax1.plot(quaia.recenter(rbins_chi2), cf_matter_chi2[j], linewidth = 1, linestyle = '--', color = 'green')
    ax2.axhline(b_q, linewidth = 2.5, color = 'darkblue')

    ax2.errorbar(quaia.recenter(rbins_chi2), b_cf_chi2[j], linewidth = 2.5, linestyle = '--', markeredgewidth = 2.5, capsize = 2.5,
                 color = 'purple', yerr = np.sqrt(np.diag(C)), label = '$b_{eff}(s)$')
    ax2.axhline(b_eff_cf20[0], linewidth = 2.5, color = 'orange', linestyle = '--')
    ax2.fill_betweenx(np.linspace(0, 10), x1 = quaia.recenter(rbins_chi2)[0], x2 = 30, color = 'grey', 
                      alpha = 0.5)
    ax2.fill_betweenx(np.linspace(0, 10), x1 = 80, x2 = quaia.recenter(rbins_chi2)[-1], color = 'grey', 
                      alpha = 0.5)
    
    ax1.set_title('$G<{}: L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(G_hi, L_bol[j]))
    ax1.set_yscale('log')
    ax1.set_xlim(quaia.recenter(rbins_chi2)[0], quaia.recenter(rbins_chi2)[-1])
    ax1.set_xticklabels([])
    ax1.set_ylim(ylim)
    ax1.legend()

    ax2.set_xlim(quaia.recenter(rbins_chi2)[0], quaia.recenter(rbins_chi2)[-1])
    ax2.set_ylim(0, 10)
    
    if (j == 0) or (j == 3):
        ax1.set_ylabel(r'$\xi(s)$')
        ax2.set_ylabel(r'$b(s)$')

    else:
        ax1.set_yticklabels([])
        ax2.set_yticklabels([])

    ax2.set_xlabel(r'$s$ $[h^{-1}$ Mpc]') # 
            
    if j % 2 != 0:
        k+=4

custom_lines = [Line2D([0], [0], color = 'orange', linestyle = '--', linewidth = 2.5),
                mpatches.Patch(color='grey', alpha = 0.5),
                Line2D([0], [0], color = 'lightgreen', linestyle = '-', linewidth = 2.5),
                Line2D([0], [0], color = 'green', linestyle = '--', linewidth = 1), 
                Line2D([0], [0], color = 'red', linestyle = 'none', marker = 'o', linewidth = 2.5)]
second_legend = ax2.legend(custom_lines, [r'${b_{eff, 20}}^2\xi_m$', 'scales excluded from fit', 
                                          r'$\xi_{{q,2h}}(f_{{duty}}=10^{{{:.2f}}}, M_{{min}}=10^{{{:.2f}}}M_\odot)$'.format(np.log10(fduty[0]), 
                                                                                                                             M_min_array[0]), r'$\xi_{{m,2h}}$',
                                          r'Quaia'], bbox_to_anchor = (1.5, 2.1), loc='upper center')
fig.add_artist(second_legend)

ax2.legend()

plt.show()
# Out:
# <>:63: SyntaxWarning: invalid escape sequence '\m'
# <>:63: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_20608/3794079928.py:63: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_title('$G<{}: L_\mathrm{{bol}}\geq10^{{{:.1f}}}$ [erg $\mathrm{{s}}^{{-1}}]$'.format(G_hi, L_bol[j]))

# %%
fig = plt.figure(figsize = (10, 8))
labels_cf = ['qq', r'$\xi_{2h}$']
gs = gridspec.GridSpec(1, 3, width_ratios = [1, 0.05, 0.05], wspace = 0)
ax1 = fig.add_subplot(gs[0])
    
b_q = [cf_2h(bins_M_min[j], n_m_array[j], a_zbin[j], cosmo_planck18, cf_chi2[j], 
             recenter = False)[1] for j in range(len(L_bol))]
ax1.plot(L_bol, b_q, linewidth = 2.5, color = 'lightgreen', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))

b_q = [cf_2h(np.logspace(np.log10(M_min_fit[j]), M_max, 79), np.ones(np.shape(bins))*fduty_fit[j], a_zbin[j], cosmo_planck18, 
             cf_chi2[j], recenter = False)[1] for j in range(len(L_bol))]
ax1.plot(L_bol, b_q, linewidth = 2.5, color = 'darkblue', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))

for k in range(len(bins)):
    b_q = [cf_2h(np.logspace(np.log10(M_min_fit[j])-1+k/int(len(bins)/2), M_max, 79), np.ones(np.shape(bins))*fduty_fit[j], a_zbin[j], 
                 cosmo_planck18, cf_chi2[j], recenter = False)[1] for j in range(len(L_bol))]
    ax1.plot(L_bol, b_q, linewidth = 2.5, color = cmap_M_min[k], zorder = 0) # color = cmaps[i][j], alpha = (l+1)/len(bins))

ax1.plot(L_bol, b_quaia(1.26, a_zbin), linestyle = '-.', linewidth = 2.5, 
         label = 'Piccirilli et al. 2024 (GMV)', color = 'green') # eq 3.6 in https://arxiv.org/abs/2402.05761
ax1.plot(L_bol, b_quaia(1.15, a_zbin), linestyle = '-.', linewidth = 2.5, 
         label = 'Piccirilli et al. 2024 (No-TT)', color = 'purple') # eq 3.6 in https://arxiv.org/abs/2402.05761
ax1.plot(L_bol, b_eboss(zbin), linestyle = '--', linewidth = 2.5, label = 'Laurent et al. 2017', 
         color = 'black') # eq 3.6 in https://arxiv.org/abs/2402.05761

ax1.axhline(b_cf20[0], linestyle = ':', linewidth = 2.5, label = r'$b_{\xi, 20}$', color = 'orange') 
ax1.axhline(b_wp20[0], linestyle = ':', linewidth = 2.5, label = '$b_{w_p, 20}$', color = 'red') 

ax1.set_title('$G<{}$'.format(G_hi))

ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
ax1.set_xlim(L_bol[0], L_bol[-1])
ax1.set_ylabel(r'$b_q$')

custom_lines = [Line2D([0], [0], color = 'lightgreen', linestyle = ':', linewidth = 2.5),
                Line2D([0], [0], color = 'darkblue', linestyle = ':', linewidth = 2.5),
                Line2D([0], [0], color = 'green', linestyle = '-.', linewidth = 2.5), 
                Line2D([0], [0], color = 'purple', linestyle = '-.', linewidth = 2.5),
                Line2D([0], [0], color = 'black', linestyle = '--', linewidth = 2.5), 
                Line2D([0], [0], color = 'orange', linestyle = ':', linewidth = 2.5), 
                Line2D([0], [0], color = 'red', linestyle = ':', linewidth = 2.5)]
second_legend = ax1.legend(custom_lines, [r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0]), 
                                          '$\chi^2$ minimization', 'Piccirilli et al. 2024 (GMV)', 'Piccirilli et al. 2024 (No-TT)', 
                                          'Laurent et al. 2017', r'$b_{\xi, 20}$', '$b_{w_p, 20}$'], ncol = 2, bbox_to_anchor = (0.5, -0.15), 
                           loc='upper center')
fig.add_artist(second_legend)

cbar = fig.colorbar(cm.ScalarMappable(cmap=palette_M_min, norm = matplotlib.colors.Normalize(vmin=-1, vmax = 1)), cax = fig.add_subplot(gs[:,-1]), 
                    label = '$\Delta \log_{10}(M_{min}/M_\odot)$')
plt.show()
# Out:
# <>:31: SyntaxWarning: invalid escape sequence '\l'
# <>:43: SyntaxWarning: invalid escape sequence '\c'
# <>:49: SyntaxWarning: invalid escape sequence '\D'
# <>:31: SyntaxWarning: invalid escape sequence '\l'
# <>:43: SyntaxWarning: invalid escape sequence '\c'
# <>:49: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_20608/1887951258.py:31: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
# /tmp/ipykernel_20608/1887951258.py:43: SyntaxWarning: invalid escape sequence '\c'
#   '$\chi^2$ minimization', 'Piccirilli et al. 2024 (GMV)', 'Piccirilli et al. 2024 (No-TT)',
# /tmp/ipykernel_20608/1887951258.py:49: SyntaxWarning: invalid escape sequence '\D'
#   label = '$\Delta \log_{10}(M_{min}/M_\odot)$')

# %%
fig = plt.figure(figsize = (10, 8))
labels_cf = ['qq', r'$\xi_{2h}$']
gs = gridspec.GridSpec(1, 3, width_ratios = [1, 0.05, 0.05], wspace = 0)
ax1 = fig.add_subplot(gs[0])

for k in range(len(bins)):
    
    M_h = [M(np.logspace(np.log10(M_min_fit[j])-1+k/int(len(bins)/2), M_max, 79), np.ones(np.shape(bins))*fduty_fit[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[0] for j in range(len(L_bol))]
    ax1.plot(L_bol, np.log10(M_h), linewidth = 2.5, 
             label = r'$f_{{duty}}: {:.2f}\%-{:.2f}\%, M_{{min}}:{:.2f} M_\odot$'.format(fduty[0]*100, fduty[-1]*100, np.log10(bins[k])),
             color = cmap_M_min[k], zorder = 0) #, alpha = (1+k)/len(bins))
    
M_h = [M(bins_M_min[j], n_m_array[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[0] for j in range(len(L_bol))]
ax1.plot(L_bol, np.log10(M_h), linewidth = 2.5, color = 'lightgreen', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))

M_h = [M(np.logspace(np.log10(M_min_fit[j]), M_max, 79), np.ones(np.shape(bins))*fduty_fit[j], a = a_zbin[j], cosmo = cosmo_planck18, 
         recenter = False)[0] for j in range(len(L_bol))]
ax1.plot(L_bol, np.log10(M_h), linewidth = 2.5, color = 'darkblue', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))

ax1.fill_between(L_bol, [np.log10(1e12/cosmo_planck18['h'])]*len(L_bol), [np.log10(3e12/cosmo_planck18['h'])]*len(L_bol), alpha = 0.5, 
                 label = 'Chehade et al. 2016', color = 'red')
ax1.set_title('$G<{}$'.format(G_hi))
ax1.fill_between(L_bol, [np.log10(1.6e12/cosmo_planck18['h'])]*len(L_bol), [np.log10(4e12/cosmo_planck18['h'])]*len(L_bol), linewidth = 2.5, 
                 label = 'Eltvedt et al. 2024 (HOD)', alpha = 0.5, color = 'orange')
ax1.fill_between(L_bol, [13.47]*len(L_bol), [13.49]*len(L_bol), alpha = 0.5, label = 'Cordova et al. 2025 (Type I)', color = 'green')

# check redshift range and check cordova type i was right to include because conflicts with this
ax1.fill_between(L_bol, [np.log10(10**12.53/cosmo_planck18['h'])]*len(L_bol), [np.log10(10**12.62/cosmo_planck18['h'])]*len(L_bol), alpha = 0.5, 
                 label = 'Petter et al. 2023 (unobscured)', color = 'blue')

custom_lines = [Line2D([0], [0], color = 'lightgreen', linestyle = ':', linewidth = 2.5), Line2D([0], [0], color = 'darkblue', linestyle = ':', linewidth = 2.5), mpatches.Patch(color='red', alpha = 0.5), 
                mpatches.Patch(color='orange', alpha = 0.5), mpatches.Patch(color='green', alpha = 0.5), mpatches.Patch(color='blue', alpha = 0.5)]
second_legend = ax1.legend(custom_lines, [r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0]), '$\chi^2$ minimization',
                            'Chehade et al. 2016', 'Eltvedt et al. 2024 (HOD)', 'Cordova et al. 2025 (Type I)', 'Petter et al. 2023 (unobscured)'], 
                           ncol = 2, bbox_to_anchor = (0.5, -0.15), loc='upper center')
fig.add_artist(second_legend)

ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
ax1.set_ylabel(r'log$_{10}(\langle M \rangle/M_\odot)$')
ax1.set_xlim(L_bol[0], L_bol[-1])
ax1.set_ylim(12.1, 13.5)

cbar = fig.colorbar(cm.ScalarMappable(cmap=palette_M_min, norm = matplotlib.colors.Normalize(vmin=-1, vmax = 1)), cax = fig.add_subplot(gs[:,-1]), 
                    label = '$\Delta \log_{10}(M_{min}/M_\odot)$')
plt.show()
# Out:
# <>:33: SyntaxWarning: invalid escape sequence '\c'
# <>:38: SyntaxWarning: invalid escape sequence '\l'
# <>:44: SyntaxWarning: invalid escape sequence '\D'
# <>:33: SyntaxWarning: invalid escape sequence '\c'
# <>:38: SyntaxWarning: invalid escape sequence '\l'
# <>:44: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_20608/434488228.py:33: SyntaxWarning: invalid escape sequence '\c'
#   second_legend = ax1.legend(custom_lines, [r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0]), '$\chi^2$ minimization',
# /tmp/ipykernel_20608/434488228.py:38: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
# /tmp/ipykernel_20608/434488228.py:44: SyntaxWarning: invalid escape sequence '\D'
#   label = '$\Delta \log_{10}(M_{min}/M_\odot)$')

# %%
correction=np.array([])
for i in range(len(L_bol)):
    if i > 2:
        correction = np.append(correction, 1)
    else:
        # correction = np.append(correction, np.min((N_q[i]/N_exp[i], 1)))
        correction = np.append(correction, N_q[i]/N_exp[i])

# %%
fig = plt.figure(figsize = (10, 8))
labels_cf = ['qq', r'$\xi_{2h}$']
gs = gridspec.GridSpec(1, 3, width_ratios = [1, 0.05, 0.05], wspace = 0)
ax1 = fig.add_subplot(gs[0])
ylim = -7.55, -4.2

for k in range(len(bins)):
    
    n_q_theory = [M(np.logspace(np.log10(M_min_fit[j])-1+k/int(len(bins)/2), M_max, 79), np.ones(np.shape(bins))*fduty_fit[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1] for j in range(len(L_bol))]
    ax1.plot(L_bol, np.log10(n_q_theory), linewidth = 2.5, #alpha = (1+k)/len(bins),
             label = r'$f_{{duty}}: {:.2f}\%-{:.2f}\%, M_{{min}}:[{:.2f}-{:.2f}] M_\odot$'.format(fduty[0]*100, fduty[-1]*100, np.log10(bins[0]), 
                                                                                                  np.log10(bins[-1])), color = cmap_M_min[k])
    
n_q_theory, n_q_theory_fit = [], []
for j in range(len(L_bol)):
    
    n_q_theory.append(M(bins_M_min[j], n_m_array[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1])
    
    n_m=np.ones(np.shape(bins))*fduty_fit[j]
    n_q_theory_fit.append(M(np.logspace(np.log10(M_min_fit[j]), M_max, 79), n_m, a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1])

ax1.plot(L_bol, np.log10(n_q_theory), linewidth = 2.5, color = 'lightgreen', linestyle = ':') # color = cmaps[i][j], alpha = (l+1)/len(bins))
ax1.plot(L_bol, np.log10(n_q_theory_fit), linewidth = 2.5, color = 'darkblue', linestyle = ':', label = r'$\chi^2$ minimization') # color = cmaps[i][j], alpha = (l+1)/len(bins))
ax1.errorbar(L_bol, np.log10(n_q), linewidth = 2.5, marker = 'o', label = 'Quaia', color = 'red',
             yerr = [np.log10(n_q)-np.log10(np.subtract(n_q, n_q_err)), np.log10(np.add(n_q, n_q_err))-np.log10(n_q)], linestyle = 'None')
ax1.errorbar(L_bol, np.log10(n_q/correction), linewidth = 2.5, label = 'Quaia, corrected', color = 'orange', marker = 'P',
             yerr = [np.log10(n_q/correction)-np.log10(np.subtract(n_q/correction, n_q_err)), np.log10(np.add(n_q/correction, n_q_err))-np.log10(n_q/correction)], linestyle = 'None')

ax1.set_title('$G<{}$'.format(G_hi))
ax1.set_xlim(L_bol[0], L_bol[-1])

custom_lines = [Line2D([0], [0], color = 'lightgreen', linestyle = ':', linewidth = 2.5, 
                       label = r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0])),
                Line2D([0], [0], color = 'darkblue', linestyle = ':', linewidth = 2.5, 
                       label = '$\chi^2$ minimization'), 
                Line2D([0], [0], color = 'red', marker = 'o', linestyle = 'None', linewidth = 2.5, label = 'Quaia'),
                Line2D([0], [0], color = 'orange', marker = 'P', linestyle = 'None', linewidth = 2.5, label = 'Quaia, corrected')]
second_legend = ax1.legend(handles = custom_lines)
fig.add_artist(second_legend)

ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
ax1.set_ylabel(r'log$_{10}(n/(h\mathrm{Mpc}^{-1})^3)$')
ax1.set_ylim(ylim)

cbar = fig.colorbar(cm.ScalarMappable(cmap=palette_M_min, norm = matplotlib.colors.Normalize(vmin=-1, vmax = 1)), cax = fig.add_subplot(gs[:,-1]), 
                    label = '$\Delta \log_{10}(M_{min}/M_\odot)$')
plt.show()

fig = plt.figure(figsize = (10, 8))
labels_cf = ['qq', r'$\xi_{2h}$']
gs = gridspec.GridSpec(1, 3, width_ratios = [1, 0.05, 0.05], wspace = 0)
ax1 = fig.add_subplot(gs[0])
i = 1
l = 38

for k in range(len(fduty_array)):

    n_q_theory=[]
    for j in range(len(L_bol)):
        
        n_m = np.ones(np.shape(bins))*10**(np.log10(fduty_fit[j])-1+k/int(len(fduty_array)/2))
        n_q_theory.append(M(np.logspace(np.log10(M_min_fit[j]), M_max, 79), n_m, a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1])
        
    ax1.plot(L_bol, np.log10(n_q_theory), linewidth = 2.5, #alpha = (1+k)/len(bins),
             color = cmap_fduty_k[k])
    
n_q_theory = [M(bins_M_min[j], n_m_array[j], a = a_zbin[j], cosmo = cosmo_planck18, recenter = False)[1] for j in range(len(L_bol))]
ax1.plot(L_bol, np.log10(n_q_theory), linewidth = 2.5, color = 'lightgreen', linestyle = ':', 
         label = r'$\log_{{10}}(M_{{min}}/M_\odot)={:.2f}$'.format(M_min_array[0])) # color = cmaps[i][j], alpha = (l+1)/len(bins)) np.log10(bins[l])

ax1.plot(L_bol, np.log10(n_q_theory_fit), linewidth = 2.5, color = 'darkblue', linestyle = ':', label = r'$\chi^2$ minimization') # color = cmaps[i][j], alpha = (l+1)/len(bins))

ax1.errorbar(L_bol, np.log10(n_q), linewidth = 2.5, marker = 'o', label = 'Quaia', color = 'red',
             yerr = [np.log10(n_q)-np.log10(np.subtract(n_q, n_q_err)), np.log10(np.add(n_q, n_q_err))-np.log10(n_q)], linestyle = 'None')
ax1.errorbar(L_bol, np.log10(n_q/correction), linewidth = 2.5, label = 'Quaia, corrected', color = 'orange', marker = 'P',
             yerr = [np.log10(n_q/correction)-np.log10(np.subtract(n_q/correction, n_q_err)), np.log10(np.add(n_q/correction, n_q_err))-np.log10(n_q/correction)], linestyle = 'None')
ax1.set_title('$G<{}$'.format(G_hi))

ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
ax1.set_ylabel(r'log$_{10}(n/(h\mathrm{Mpc}^{-1})^3)$')
ax1.set_ylim(ylim)
ax1.legend()
ax1.set_xlim(L_bol[0], L_bol[-1])

cbar = fig.colorbar(cm.ScalarMappable(cmap=palette_M_min, norm = matplotlib.colors.Normalize(vmin=-1, vmax = 1)), cax = fig.add_subplot(gs[:,-1]), 
                    label = '$\Delta \log_{10}(f_{duty})$')
plt.show()
# Out:
# <>:35: SyntaxWarning: invalid escape sequence '\c'
# <>:41: SyntaxWarning: invalid escape sequence '\l'
# <>:46: SyntaxWarning: invalid escape sequence '\D'
# <>:79: SyntaxWarning: invalid escape sequence '\l'
# <>:86: SyntaxWarning: invalid escape sequence '\D'
# <>:35: SyntaxWarning: invalid escape sequence '\c'
# <>:41: SyntaxWarning: invalid escape sequence '\l'
# <>:46: SyntaxWarning: invalid escape sequence '\D'
# <>:79: SyntaxWarning: invalid escape sequence '\l'
# <>:86: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_20608/1524766846.py:35: SyntaxWarning: invalid escape sequence '\c'
#   label = '$\chi^2$ minimization'),
# /tmp/ipykernel_20608/1524766846.py:41: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
# /tmp/ipykernel_20608/1524766846.py:46: SyntaxWarning: invalid escape sequence '\D'
#   label = '$\Delta \log_{10}(M_{min}/M_\odot)$')
# /tmp/ipykernel_20608/1524766846.py:79: SyntaxWarning: invalid escape sequence '\l'
#   ax1.set_xlabel('$\log_{10}(L_\mathrm{bol}/(\mathrm{erg }s^{-1}))$')
# /tmp/ipykernel_20608/1524766846.py:86: SyntaxWarning: invalid escape sequence '\D'
#   label = '$\Delta \log_{10}(f_{duty})$')

# %% [markdown]
# ### Check that $N_\mathrm{exp}=N_\mathrm{obs}/$correction, where correction$=N_\mathrm{obs}/N_\mathrm{exp}$

# %%
N_exp, N_q/correction, N_q
# Out:
# ([<Quantity 884424.93148823>,
#   <Quantity 283877.2052528>,
#   <Quantity 76144.94091113>,
#   <Quantity 17397.26170553>,
#   <Quantity 4354.30722838>],
#  <Quantity [884424.93148823, 283877.2052528 ,  76144.94091113,
#              17294.        ,   1549.        ]>,
#  [225780, 214489, 111779, 17294, 1549])

# %% [markdown]
# # Recreate Figure 3 of https://arxiv.org/abs/2407.21568

# %%
zbin_array = np.linspace(0,1.5,9)
zbin_array
# Out:
# array([0.    , 0.1875, 0.375 , 0.5625, 0.75  , 0.9375, 1.125 , 1.3125,
#        1.5   ])

# %%
n_quaia, N_quaia = {L: [] for L in L_bol}, {L: [] for L in L_bol}
N_exp = {L: [] for L in L_bol}
b = 10
for i in range(len(L_bol)):  
    
    for j in range(len(zbin_array)-1):
        
        # try:
        
        tab_datahi_mask_zbin0, tab_randhi_mask_zbin0, key_zbin0, _, _, _, selfunc_hi_bin0, mask_datahi_bin0 = quaia.make_bins(G_hi, [j, i], True, ['z', 'L_bol'], 
                                                                                             bins = [zbin_array, L_bol], tab_gcat_type = 'data', 
                                                                                              method = ['minmax', 'threshold'], fac_rand = fac_rand, 
                                                                                              mask_type = 'b', b = b, n_bins = [None, None], precision = True)

        N = len(tab_datahi_mask_zbin0)
        # lon, lat = hp.pix2ang(NSIDE, range(hp.nside2npix(NSIDE)), lonlat = True)
        # c = SkyCoord(ra=lon*u.degree, dec=lat*u.degree)
        # f_sky = 1/(4*np.pi)*np.sum(selfunc_hi_bin0[np.abs(c.galactic.b.value)>=b]*hp.nside2pixarea(NSIDE))
        f_sky = 1/(4*np.pi)*np.sum(selfunc_hi_bin0*hp.nside2pixarea(NSIDE))
        V = f_sky*(Planck18.comoving_volume(1)-Planck18.comoving_volume(0))*cosmo_planck18['h']**3/u.h**3

        N_quaia[L_bol[i]].append(N/(1-np.sin(np.radians(10))))
        # N_quaia[L_bol[i]].append(N)
        n_quaia[L_bol[i]].append(N/V.value)

        M_array = m_AB(np.logspace(L_bol[i], 49, 200)).value[::-1]
        z_array = np.linspace(zbin_array[j], zbin_array[j+1], 200)
        # dz, dM = np.meshgrid(quaia.recenter(z_array), M_array)
        dz, dM = np.meshgrid(z_array, M_array)
        dV_dz = f_sky*Planck18.differential_comoving_volume(dz)*4*np.pi*u.sr #*cosmo_quaia['h']**3 # convert to 1/Mpc^3
        # dV_dz = f_sky*(Planck18.comoving_volume(z_array[1:])-Planck18.comoving_volume(z_array[:-1]))

        # phi_dM = np.trapz(phi(dz, dM)*dV_dz, quaia.recenter(z_array))
        phi_dM = np.trapz(phi(dz, dM)*dV_dz, z_array)
        N_exp[L_bol[i]].append(np.trapz(phi_dM, M_array)*u.mag)

        try:
            print(np.log10(np.min(tab_datahi_mask_zbin0['L_bol'])))
            print(np.log10(np.max(tab_datahi_mask_zbin0['L_bol'])))
        except:
            print(len(tab_datahi_mask_zbin0))

        # except:
        #     print('{}<z<={}, log10(Lbolmin/(erg/s)))={} not yet loaded'.format(zbin_array[j], zbin_array[j+1], L_bol[i]))
# Out:
# Random catalog is not computed, do not use output
# G20.5_zmin0.0000zmax0.1875_Lbolmin44.5: 0.03              3054 vs 3144
# 44.50246918699042
# 45.89055707200349
# Random catalog is not computed, do not use output
# G20.5_zmin0.1875zmax0.3750_Lbolmin44.5: 0.02              31619 vs 32168
# 44.50479194641029
# 46.858390262469534
# Random catalog is not computed, do not use output
# G20.5_zmin0.3750zmax0.5625_Lbolmin44.5: 0.02              61769 vs 62859
# 44.77377560738918
# 47.36289233717049
# Random catalog is not computed, do not use output
# G20.5_zmin0.5625zmax0.7500_Lbolmin44.5: 0.02              77061 vs 78594
# 44.89729694034303
# 47.47298552251411
# Random catalog is not computed, do not use output
# G20.5_zmin0.7500zmax0.9375_Lbolmin44.5: 0.02              104599 vs 106682
# 45.01577667148312
# 47.77362242404885
# Random catalog is not computed, do not use output
# G20.5_zmin0.9375zmax1.1250_Lbolmin44.5: 0.02              119288 vs 121266
# 44.81350162617635
# 47.88659067116192
# G20.5_zmin1.1250zmax1.3125_Lbolmin44.5: 0.01              123955 vs 125675
# 45.28270339059974
# 48.01104074308557
# G20.5_zmin1.3125zmax1.5000_Lbolmin44.5: 0.01              135517 vs 136960
# 45.43570574084397
# 48.16419736144286
# G20.5_zmin0.0000zmax0.1875_Lbolmin45.0: 0.02              1188 vs 1216
# 45.00007003181955
# 45.89055707200349
# G20.5_zmin0.1875zmax0.3750_Lbolmin45.0: 0.02              20409 vs 20859
# 45.00001358351731
# 46.858390262469534
# G20.5_zmin0.3750zmax0.5625_Lbolmin45.0: 0.02              58848 vs 59913
# 45.000020949133024
# 47.36289233717049
# G20.5_zmin0.5625zmax0.7500_Lbolmin45.0: 0.02              77060 vs 78593
# 45.01348513080752
# 47.47298552251411
# Random catalog is not computed, do not use output
# G20.5_zmin0.7500zmax0.9375_Lbolmin45.0: 0.02              104599 vs 106682
# 45.01577667148312
# 47.77362242404885
# Random catalog is not computed, do not use output
# G20.5_zmin0.9375zmax1.1250_Lbolmin45.0: 0.02              119287 vs 121265
# 45.249716815349785
# 47.88659067116192
# Random catalog is not computed, do not use output
# G20.5_zmin1.1250zmax1.3125_Lbolmin45.0: 0.01              123955 vs 125675
# 45.28270339059974
# 48.01104074308557
# Random catalog is not computed, do not use output
# G20.5_zmin1.3125zmax1.5000_Lbolmin45.0: 0.01              135517 vs 136960
# 45.43570574084397
# 48.16419736144286
# Random catalog is not computed, do not use output
# G20.5_zmin0.0000zmax0.1875_Lbolmin45.5: 0.03              59 vs 61
# 45.50302638690508
# 45.89055707200349
# Random catalog is not computed, do not use output
# G20.5_zmin0.1875zmax0.3750_Lbolmin45.5: 0.03              2628 vs 2699
# 45.50001866470229
# 46.858390262469534
# Random catalog is not computed, do not use output
# G20.5_zmin0.3750zmax0.5625_Lbolmin45.5: 0.02              11656 vs 11948
# 45.50007210799107
# 47.36289233717049
# Random catalog is not computed, do not use output
# G20.5_zmin0.5625zmax0.7500_Lbolmin45.5: 0.02              30949 vs 31697
# 45.50000339477892
# 47.47298552251411
# Random catalog is not computed, do not use output
# G20.5_zmin0.7500zmax0.9375_Lbolmin45.5: 0.02              74835 vs 76442
# 45.50000331317092
# 47.77362242404885
# Random catalog is not computed, do not use output
# G20.5_zmin0.9375zmax1.1250_Lbolmin45.5: 0.02              115841 vs 117770
# 45.50000132818535
# 47.88659067116192
# Random catalog is not computed, do not use output
# G20.5_zmin1.1250zmax1.3125_Lbolmin45.5: 0.01              123903 vs 125623
# 45.50098295251347
# 48.01104074308557
# Random catalog is not computed, do not use output
# G20.5_zmin1.3125zmax1.5000_Lbolmin45.5: 0.01              135516 vs 136959
# 45.509513027346586
# 48.16419736144286
# Random catalog is not computed, do not use output
# G20.5_zmin0.0000zmax0.1875_Lbolmin46.0: nan              0 vs 0
# 0
# Random catalog is not computed, do not use output
# G20.5_zmin0.1875zmax0.3750_Lbolmin46.0: 0.03              294 vs 304
# 46.00027710852407
# 46.858390262469534
# Random catalog is not computed, do not use output
# G20.5_zmin0.3750zmax0.5625_Lbolmin46.0: 0.02              1254 vs 1279
# 46.00041875337968
# 47.36289233717049
# Random catalog is not computed, do not use output
# G20.5_zmin0.5625zmax0.7500_Lbolmin46.0: 0.02              3798 vs 3876
# 46.000070291863885
# 47.47298552251411
# Random catalog is not computed, do not use output
# G20.5_zmin0.7500zmax0.9375_Lbolmin46.0: 0.02              11759 vs 12046
# 46.000015358263
# 47.77362242404885
# Random catalog is not computed, do not use output
# G20.5_zmin0.9375zmax1.1250_Lbolmin46.0: 0.02              26305 vs 26870
# 46.00000661667448
# 47.88659067116192
# Random catalog is not computed, do not use output
# G20.5_zmin1.1250zmax1.3125_Lbolmin46.0: 0.02              46462 vs 47255
# 46.00000066822316
# 48.01104074308557
# Random catalog is not computed, do not use output
# G20.5_zmin1.3125zmax1.5000_Lbolmin46.0: 0.01              82625 vs 83646
# 46.000004560889636
# 48.16419736144286
# Random catalog is not computed, do not use output
# G20.5_zmin0.0000zmax0.1875_Lbolmin46.5: nan              0 vs 0
# 0
# Random catalog is not computed, do not use output
# G20.5_zmin0.1875zmax0.3750_Lbolmin46.5: 0.00              31 vs 31
# 46.50637098919977
# 46.858390262469534
# Random catalog is not computed, do not use output
# G20.5_zmin0.3750zmax0.5625_Lbolmin46.5: 0.02              140 vs 143
# 46.50081819496038
# 47.36289233717049
# Random catalog is not computed, do not use output
# G20.5_zmin0.5625zmax0.7500_Lbolmin46.5: 0.01              289 vs 291
# 46.50099428399179
# 47.47298552251411
# Random catalog is not computed, do not use output
# G20.5_zmin0.7500zmax0.9375_Lbolmin46.5: 0.02              1131 vs 1157
# 46.500104244430794
# 47.77362242404885
# Random catalog is not computed, do not use output
# G20.5_zmin0.9375zmax1.1250_Lbolmin46.5: 0.02              2815 vs 2868
# 46.500289453880825
# 47.88659067116192
# Random catalog is not computed, do not use output
# G20.5_zmin1.1250zmax1.3125_Lbolmin46.5: 0.02              5546 vs 5648
# 46.50002501818945
# 48.01104074308557
# Random catalog is not computed, do not use output
# G20.5_zmin1.3125zmax1.5000_Lbolmin46.5: 0.01              12053 vs 12229
# 46.500013325366474
# 48.16419736144286

# %%
colors = 'grey', 'yellow', 'red', 'green', 'blue'

# %%
fig = plt.figure(figsize = (10, 10))
gs = gridspec.GridSpec(2, 1, height_ratios = [1, 0.25], hspace = 0)
ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])

# try:
    
for i in range(len(L_bol)):
    ax1.scatter(quaia.recenter(zbin_array)[:len(N_quaia[L_bol[i]])], N_quaia[L_bol[i]], label = 'Quaia', color = colors[i], alpha = 0.5)
    ax1.plot(quaia.recenter(zbin_array)[:len(N_quaia[L_bol[i]])], N_exp[L_bol[i]], linestyle = '--', label = '$L_\mathrm{{bol}}\geq 10^{{{}}} \mathrm{{erg }}s^{{-1}}$'.format(L_bol[i]), color = colors[i], 
             alpha = 0.5)
    ax2.plot(quaia.recenter(zbin_array)[:len(N_quaia[L_bol[i]])],np.array(N_quaia[L_bol[i]])/N_exp[L_bol[i]], color = colors[i], marker = 'o', linestyle = '--', alpha = 0.5)
        
# except:
#     pass

ax1.set_ylabel('$N_\mathrm{QSO, zbin}$')
ax1.set_yscale('log')
ax1.set_xlim(0,1.5)
ax1.set_xticklabels([])
ax1.set_ylim(1e-1, 5e6)

ax2.axhline(1, linestyle = ':')
ax2.set_xlabel('$z$')
ax2.set_ylabel(r'$\frac{N_\mathrm{Quaia}}{N_\mathrm{exp}}$')
ax2.set_xlim(0,1.5)
ax2.set_ylim(-0.25, 3.5)

custom_lines = [Line2D([0], [0], color = 'black', linestyle = 'none', marker = 'o'), Line2D([0], [0], color = 'black', linestyle = '--')]
second_legend = ax1.legend(custom_lines, [r'$N_\mathrm{Quaia}$', '$N_\mathrm{exp}$'])
fig.add_artist(second_legend)

custom_lines = [mpatches.Patch(color=color, alpha = 0.5) for color in colors]
first_legend = ax1.legend(custom_lines, ['$L_\mathrm{{bol}}\geq 10^{{{}}} \mathrm{{erg }}s^{{-1}}$'.format(L) for L in L_bol], loc = 'lower right')
fig.add_artist(first_legend)

plt.show()
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:17: SyntaxWarning: invalid escape sequence '\m'
# <>:30: SyntaxWarning: invalid escape sequence '\m'
# <>:34: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:17: SyntaxWarning: invalid escape sequence '\m'
# <>:30: SyntaxWarning: invalid escape sequence '\m'
# <>:34: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_13787/3120758650.py:10: SyntaxWarning: invalid escape sequence '\m'
#   ax1.plot(quaia.recenter(zbin_array)[:len(N_quaia[L_bol[i]])], N_exp[L_bol[i]], linestyle = '--', label = '$L_\mathrm{{bol}}\geq 10^{{{}}} \mathrm{{erg }}s^{{-1}}$'.format(L_bol[i]), color = colors[i],
# /tmp/ipykernel_13787/3120758650.py:17: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_ylabel('$N_\mathrm{QSO, zbin}$')
# /tmp/ipykernel_13787/3120758650.py:30: SyntaxWarning: invalid escape sequence '\m'
#   second_legend = ax1.legend(custom_lines, [r'$N_\mathrm{Quaia}$', '$N_\mathrm{exp}$'])
# /tmp/ipykernel_13787/3120758650.py:34: SyntaxWarning: invalid escape sequence '\m'
#   first_legend = ax1.legend(custom_lines, ['$L_\mathrm{{bol}}\geq 10^{{{}}} \mathrm{{erg }}s^{{-1}}$'.format(L) for L in L_bol], loc = 'lower right')
